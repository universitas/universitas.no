# %%
nn = Contributor.objects.get(display_name='Nomen Nescio')

# %%
for bl in nn.byline_set.all():
    try:
        byline = json.loads(bl.story.legacy_html_source)[0]['fields']['byline']
    except TypeError:
        byline = bl.story.bylines.all()
    print(bl.story.pk)
    print(byline)
# Out:
# 57109
# Hogne Ulla er nestleder i NSO-NHHS.
# 57073
# Warsan Ismail er blogger og student.
# 57047
# Ove Vanebo er leder i Fremskrittspartiets Ungdom og har juristutdanning.
# 57017
# Kyrre Lekve er statssekretær for Tora Aasland (SV), statsråd for forskning og høyere utdanning
# 57017
# Kyrre Lekve er statssekretær for Tora Aasland (SV), statsråd for forskning og høyere utdanning
# 56948
# Warsan Ismail er student og blogger.
# 56905
# Kyrre Lekve er statssekretær for Tora Aasland (SV), statsråd for forskning og høyere utdanning.
# 56905
# Kyrre Lekve er statssekretær for Tora Aasland (SV), statsråd for forskning og høyere utdanning.
# 56902
# Ingrid Eidsheim Daae     Skjalg Bøhmer Vold (foto)
# 56690
# Axel Munthe-Kaas Hærland Skjalg Bøhmer Vold (foto)
# 56206
# Hans J. Skjong •  Øyvind Gallefoss • Hans Hval (illustrasjonsfoto) (foto)
# 56198
# MOSS/OSLO: Ingeborg Huse Amundsen • NEW YORK: Emil Flatø • Skjalg Bøhmer Vold (foto)
# 55835
# ...

# %%
json.loads(bl.story.legacy_prodsys_source)[0]['fields']
bl.story.bylines.all()
# Out:
# [<Contributor: Hans Dalane-Hval>, <Contributor: Sunniva R. Skjeggestad>, <Contributor: Nomen Nescio>]

# %%
bl.story.publication_status
# Out:
# 10

# %%
story =bl.story

# %%
story.

# %%
val = 50
i = 1
while val:
    print(i, val)
    i += 1
    val = int(val*.95)
# Out:
# 1 50
# 2 47
# 3 44
# 4 41
# 5 38
# 6 36
# 7 34
# 8 32
# 9 30
# 10 28
# 11 26
# 12 24
# 13 22
# 14 20
# 15 19
# 16 18
# 17 17
# 18 16
# 19 15
# 20 14
# 21 13
# 22 12
# 23 11
# 24 10
# 25 9
# 26 8
# 27 7
# 28 6
# 29 5
# 30 4
# 31 3
# 32 2
# 33 1
