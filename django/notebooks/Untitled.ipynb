# %%
from utils import content_factory
content_factory.random_image(size=(1000, 500))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7FC15B12C438>

# %%
from PIL import Image
im = ImageFile.objects.last()

# %%
path =im.thumb(100,100)
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7FC15918D128>
