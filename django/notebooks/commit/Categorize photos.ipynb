# %%
import re
def re_find(expression, haystack):
    try:
        return re.search(expression, haystack).groups()[0]
    except AttributeError:
        return ''

def get_initials_from_file_name(filename):
    return re_find(r'-(?P<initials>[A-Z]+)((-NR)?-\d+)?(-*\d+-of-\d+)?(_\w{7})?\.\w+$', filename)

# %%
def active_photographers(when=None):
    photographer = Position.objects.get(title='fotograf')
    stints = Stint.objects.filter(position=photographer)
    if when:
        stints = stints.active(when)
    contributors = Contributor.objects.filter(pk__in=stints.values_list('contributor', flat=True))
    return contributors
   
active_photographers()
# Out:
# <ContributorQuerySet [<Contributor: Mari Lund Haanshus>, <Contributor: Audun Halaas>, <Contributor: Khai Nguyen>, <Contributor: Karsten Eig>, <Contributor: Hilde Raa>, <Contributor: Bjørn Brekke>, <Contributor: Berit Andreassen>, <Contributor: Åshild Støylen>, <Contributor: Håkon Mosvold>, <Contributor: Håkon Rasmus Bergseth>, <Contributor: Solveig Schanke Eikum>, <Contributor: Halvor Finess Tretvoll>, <Contributor: Fredrik Arff>, <Contributor: Erik Møller Solheim>, <Contributor: Mona Tandsether>, <Contributor: Sunniva Trengereid>, <Contributor: Maria Mår Johansen>, <Contributor: Audun Kolstad Wiig>, <Contributor: Kristian Ridder-Nilsen>, <Contributor: Ellinor Bent Dalbye>, '...(remaining elements truncated)...']>

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.ERROR)
from utils.disconnect_signals import disconnect_signals

sjur = Contributor.objects.search('Sjur Stølen').first()
sjur.initials='SGS'
sjur.save()
ingrid = Contributor.objects.search('Ingrid Dalen Rogstad').first()
ingrid.initials = 'IDR'
ingrid.save()
kvammen = Contributor.objects.search('Anders Nordmo Kvammen').first()
kvammen.initials = 'ANK'
kvammen.save()

lookup = {cn.initials: cn for cn in Contributor.objects.exclude(initials='') if 1 < len(cn.initials) < 4}
lookup['HHH'] = lookup['HDH']
lookup['TWM'] = lookup['TM']
lookup['AAGS'] = lookup['AS']
lookup['AHA'] = lookup['AH']
lookup['PP'] = lookup['PPB']

lookup
# Out:
# {'AA': <Contributor: Anders Aasbø>,
#  'AAGS': <Contributor: Alf Simensen>,
#  'AAH': <Contributor: Anders Aavik Hagen>,
#  'ABE': <Contributor: Åshild Bekke Eidem>,
#  'ABP': <Contributor: Amanda Borch Pacheco>,
#  'ABV': <Contributor: Anne Bergitte Viken>,
#  'AC': <Contributor: Angélique Culvin>,
#  'AFL': <Contributor: Anders Firing Lunde>,
#  'AH': <Contributor: Aurora Hannisdal>,
#  'AHA': <Contributor: Aurora Hannisdal>,
#  'AJ': <Contributor: Aslak Johannesen>,
#  'AK': <Contributor: Astrid Karstensen>,
#  'AKV': <Contributor: Aksel Kjær Vidnes>,
#  'AKW': <Contributor: Audun Kolstad Wiig>,
#  'ALG': <Contributor: Anne Leifsdatter Grønlund>,
#  'AM': <Contributor: Aleksander Myklebust>,
#  'AN': <Contributor: Adrian Nielsen>,
#  'ANK': <Contributor: Anders Nordmo Kvammen>,
#  'AO': <Contributor: Anne Ogundipe>,
#  'AOB': <Contributor: Amanda O. Berg>,
#  'AQG': <Contributor: Alexander Qvale Gilje>,
#  'AR': <Contributor: Anders Rikstad>,
#  'AS': <Contributor: Alf Simensen>,
#  'AV': <Contributor: Anders Veberg>,
#  'AW': <Contributor: Anna Werenskjold>,
#  'BA': <Contributor: Berit Andreassen>,
#  'BB': <Contributor: Bjørn Brekke>,
#  'BEB': <Contributor: Benedicte Elisabeth Bjerknes>,
#  'BKB': <Contributor: Bjørnar Konglevoll Bekkevard>,
#  'BL': <Contributor: Bendik Løve>,
#  'BNM': <Contributor: Birte Nystad Magnussen>,
#  'BO': <Contributor: Brian Olguin>,
#  'BS': <Contributor: Benedikte Skarvik>,
#  'CAL': <Contributor: Camilla Alexandra Lie>,
#  'CB': <Contributor: Christian Breidlid>,
#  'CE': <Contributor: Christine Erlbeck>,
#  'CK': <Contributor: Christine Karijord>,
#  'CL': <Contributor: Christian Lyche>,
#  'CT': <Contributor: Camilla Tully>,
#  'DC': <Contributor: Damir Cvetojevic>,
#  'DK': <Contributor: Dorthe Karlsen>,
#  'DV': <Contributor: David Vilder>,
#  'EBD': <Contributor: Ellinor Bent Dalbye>,
#  'EBJ': <Contributor: Eirik Bryhn Jacobsen>,
#  'EDD': <Contributor: Erlend Dalhaug Daae>,
#  'EE': <Contributor: Ellen Engelstad>,
#  'EG': <Contributor: Espen Gleditsch>,
#  'EJ': <Contributor: Elisabeth Johansen>,
#  'EK': <Contributor: Ena Kreso>,
#  'EL': <Contributor: Erik Løvold>,
#  'EM': <Contributor: Eivind Marienborg>,
#  'EMS': <Contributor: Erik Møller Solheim>,
#  'EP': <Contributor: Evelyn Pecori>,
#  'ES': <Contributor: Eivind Sørlie>,
#  'ESA': <Contributor: Elisabeth Sperre Alnes>,
#  'ESL': <Contributor: Ellen Sofie Lauritzen>,
#  'ET': <Contributor: Eir Torvik>,
#  'EW': <Contributor: Eskil Wie>,
#  'FA': <Contributor: Fredrik Arff>,
#  'FL': <Contributor: Frank Lande>,
#  'FP': <Contributor: Fredrik Poulsen>,
#  'GH': <Contributor: Gisle Hellsten>,
#  'GKJ': <Contributor: Grethe Kielland-Jenssen>,
#  'GM': <Contributor: Geir Molnes>,
#  'GO': <Contributor: Gard Oterholm>,
#  'GS': <Contributor: Guro Sommer>,
#  'HAS': <Contributor: Henrik Andersen Sveinsson>,
#  'HB': <Contributor: Håkon Benjaminsen>,
#  'HBR': <Contributor: Hilde Berteig Rustan>,
#  'HD': <Contributor: Henriette Dæhli>,
#  'HDH': <Contributor: Hans Dalane-Hval>,
#  'HE': <Contributor: Henrik Evertsson>,
#  'HFB': <Contributor: Harald Fagerheim Bugge>,
#  'HFT': <Contributor: Halvor Finess Tretvoll>,
#  'HG': <Contributor: Helle Gannestad>,
#  'HH': <Contributor: Hanna Hjardar>,
#  'HHH': <Contributor: Hans Dalane-Hval>,
#  'HJK': <Contributor: Haakon Jamtli Kristiansen>,
#  'HK': <Contributor: Helene Kristiansen>,
#  'HKH': <Contributor: Hanna Kristin Hjardar>,
#  'HL': <Contributor: Håken Lid>,
#  'HM': <Contributor: Håkon Mosvold>,
#  'HMK': <Contributor: Hanna Magnussen Krogvold>,
#  'HN': <Contributor: Helena Nielsen>,
#  'HOH': <Contributor: Hanne O. Hvattum>,
#  'HOR': <Contributor: Hans Ole Rian>,
#  'HR': <Contributor: Hilde Raa>,
#  'HRB': <Contributor: Håkon Rasmus Bergseth>,
#  'HS': <Contributor: Hanna Skotheim>,
#  'IB': <Contributor: Idar Bergfjord>,
#  'IDR': <Contributor: Ingrid Dahlen Rogstad>,
#  'IHG': <Contributor: Ida Helen Gøytil>,
#  'IHK': <Contributor: Ingrid Hjellbakk Kvamstø>,
#  'IHS': <Contributor: Ida Hove Solberg>,
#  'IJ': <Contributor: Ingrid Jørgensen>,
#  'IK': <Contributor: Ivàn Kverme>,
#  'IMJ': <Contributor: Ida Marie Jahr>,
#  'IRN': <Contributor: Igor R. Nilsen>,
#  'IS': <Contributor: Ingjerd Sørli>,
#  'IST': <Contributor: Iselin Shaw of Tordarroch>,
#  'IW': <Contributor: Ida Wammer>,
#  'JB': <Contributor: Jørgen Brynhildsvoll>,
#  'JFK': <Contributor: Janni Frederiksen Kalafatis>,
#  'JH': <Contributor: Julie Hoen>,
#  'JIU': <Contributor: Journalist I Universitas>,
#  'JK': <Contributor: Jørgen Kvalsvik>,
#  'JS': <Contributor: Jo Straube>,
#  'JY': <Contributor: Jil Yngland>,
#  'KAB': <Contributor: Kristin Antonsen Brenna>,
#  'KB': <Contributor: Ketil Blom>,
#  'KE': <Contributor: Kari Eiring>,
#  'KEK': <Contributor: Kristina Elisabet Kvammen>,
#  'KG': <Contributor: Kristine Gramstad>,
#  'KH': <Contributor: Kristina Holt>,
#  'KHE': <Contributor: Kristoffer Hatteland Endresen>,
#  'KHW': <Contributor: King Ho Wong>,
#  'KK': <Contributor: Kamran Karimi>,
#  'KL': <Contributor: Klaudia Lech>,
#  'KMD': <Contributor: Kaj M. Duesund>,
#  'KN': <Contributor: Kristin Nordby>,
#  'KRN': <Contributor: Kristian Ridder-Nilsen>,
#  'LB': <Contributor: Lise Blekastad>,
#  'LF': <Contributor: Lise Falch>,
#  'LH': <Contributor: Line Hårklau>,
#  'LHR': <Contributor: Lene Hoem Røysum>,
#  'LK': <Contributor: Leo Krohn>,
#  'LMK': <Contributor: Leif Martin Kirknes>,
#  'LN': <Contributor: Lena Nielsen>,
#  'LO': <Contributor: Line Ørnes>,
#  'LOS': <Contributor: Line Ørnes Søndergaard>,
#  'LS': <Contributor: Lovise Steinkjellå>,
#  'LSN': <Contributor: Lene Sørøy Neverdal>,
#  'MAD': <Contributor: Martin Anders Dahl>,
#  'MAV': <Contributor: Marthe Amanda Vannebo>,
#  'MB': <Contributor: Michael Brøndbo>,
#  'MC': <Contributor: Matilde Clemetsen>,
#  'MD': <Contributor: Marianne Demmo>,
#  'MEL': <Contributor: Martine Engebretsen Li>,
#  'MF': <Contributor: Mia Frogner>,
#  'MGT': <Contributor: Marianne Granheim Trøyflat>,
#  'MH': <Contributor: Moabit Hilft>,
#  'MKS': <Contributor: Matthis Kleeb Solheim>,
#  'ML': <Contributor: Margrethe Løøv>,
#  'MLH': <Contributor: Mari Lund Haanshus>,
#  'MM': <Contributor: Mari Mjaaland>,
#  'MMJ': <Contributor: Maria Mår Johansen>,
#  'MNP': <Contributor: Marius N. Pettersen>,
#  'MO': <Contributor: Marte Øien>,
#  'MP': <Contributor: Martin Pauline>,
#  'MR': <Contributor: Marte Refsdal>,
#  'MRN': <Contributor: Mathea Reine-Nilsen>,
#  'MSC': <Contributor: Matilde Solberg Clemetsen>,
#  'MT': <Contributor: Mona Tandsether>,
#  'MVS': <Contributor: Margrethe Voll Storaas>,
#  'MWA': <Contributor: Magnus Weiberg–Aurdal>,
#  'MZ': <Contributor: Maral Zadeh>,
#  'NL': <Contributor: Niklas Lello>,
#  'NN': <Contributor: NN>,
#  'NPP': <Contributor: Nicolas Perez Prieto>,
#  'NPS': <Contributor: Nils Petter Strand>,
#  'NT': <Contributor: Nordis Tennes>,
#  'NW': <Contributor: Nicolay Woldsdal>,
#  'NWL': <Contributor: Nathalie Wik Lystad>,
#  'OA': <Contributor: Øyvind Aukrust>,
#  'OD': <Contributor: Odin Drønen>,
#  'OG': <Contributor: Øystein Grønvold>,
#  'OH': <Contributor: Øivind Hovland>,
#  'OHE': <Contributor: Ole Heier Engeset>,
#  'OHF': <Contributor: Ole Hjetland Falck>,
#  'OJ': <Contributor: Odin Jæger>,
#  'OL': <Contributor: Øyvind Lie>,
#  'OS': <Contributor: Olivia Salles>,
#  'OV': <Contributor: Ola Vatn>,
#  'PA': <Contributor: Paal Audestad>,
#  'PAJ': <Contributor: Philip André Johannesborg>,
#  'PAW': <Contributor: Paul Anthony Wilson>,
#  'PF': <Contributor: Petter Fløttum>,
#  'PH': <Contributor: Petter Holstad>,
#  'PP': <Contributor: Paul Patrick Børhaug>,
#  'PPB': <Contributor: Paul Patrick Børhaug>,
#  'PSS': <Contributor: Patrick da Silva Sæther>,
#  'RBF': <Contributor: Roar Blåsmo-Falnes>,
#  'RE': <Contributor: Richard Eriksen>,
#  'RO': <Contributor: Rune Olsen>,
#  'RP': <Contributor: Raisa Porsanger>,
#  'RRJ': <Contributor: Robin Røkke Johansen>,
#  'RT': <Contributor: Ragnar Trøite>,
#  'SAA': <Contributor: Simen August Askeland>,
#  'SAG': <Contributor: Sebastian Asbjørn Gabrielsen>,
#  'SB': <Contributor: Sander Brink>,
#  'SBV': <Contributor: Skjalg Bøhmer Vold>,
#  'SD': <Contributor: Sébastian Dahl>,
#  'SE': <Contributor: Silje Eide>,
#  'SEH': <Contributor: Svein Egil Hatlevik>,
#  'SGM': <Contributor: Sindre Granly Meldalen>,
#  'SGS': <Contributor: Sjur Stølen>,
#  'SH': <Contributor: Stephen Hutton>,
#  'SK': <Contributor: Silje Kleven>,
#  'SL': <Contributor: Stéphane Lelarge>,
#  'SN': <Contributor: Sara Nordby>,
#  'SOE': <Contributor: Siri Øverland Eriksen>,
#  'SR': <Contributor: Silje Ramstad>,
#  'SRH': <Contributor: Signe Rosenlund-Hauglid>,
#  'SRS': <Contributor: Sunniva R. Skjeggestad>,
#  'SS': <Contributor: Stine Stenhaug>,
#  'SSE': <Contributor: Solveig Schanke Eikum>,
#  'ST': <Contributor: Sunniva Trengereid>,
#  'STL': <Contributor: Sindre T. Lønnes>,
#  'TGR': <Contributor: Thea Grav Rosenberg>,
#  'TH': <Contributor: Terje Hoel>,
#  'TJ': <Contributor: Therese Jægtvik>,
#  'TKB': <Contributor: Thorbjørn Kringlebotn Borlaug>,
#  'TM': <Contributor: Tobias Myrland>,
#  'TN': <Contributor: Tonje Næss>,
#  'TSA': <Contributor: Toril Sunde Apelthun>,
#  'TSE': <Contributor: Thea Storøy Elnan>,
#  'TSH': <Contributor: Torbjørn Sundal Holen>,
#  'TT': <Contributor: Tonje Thilesen>,
#  'TWM': <Contributor: Tobias Myrland>,
#  'UC': <Contributor: Unni Claussen>,
#  'VB': <Contributor: Vilde Borse>,
#  'VS': <Contributor: Victoria Syslak>,
#  'WB': <Contributor: Warner Bros.>,
#  'WNN': <Contributor: Wanda Nathalie Nordstrøm>,
#  'WSC': <Contributor: Www.Statoilhydro.Com>,
#  'XP': <Contributor: Xueqi Pang>}

# %%
Contributor.objects.filter(initials='EBJ')
qs.filter(source_file__contains='EBJ')
# Out:
# <ImageFileQuerySet [<ImageFile: 08-NYH-GS-EBJ--19-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--12-of-33.jpg>, <ImageFile: 11-NYH-Stale-Wig-deep-reading-EBJ--8-of-13.jpg>, <ImageFile: 11-NYH-Stale-Wig-deep-reading-EBJ--10-of-13.jpg>, <ImageFile: 11-NYH-Stale-Wig-deep-reading-EBJ--12-of-13.jpg>, <ImageFile: 11-NYH-Stale-Wig-deep-reading-EBJ--3-of-13.jpg>, <ImageFile: 08-NYH-GS-EBJ--15-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--29-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--22-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--23-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--13-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--11-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--27-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--28-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--17-of-33.jpg>, <ImageFile: 11-NYH-Stale-Wig-deep-reading-EBJ--11-of-13.jpg>, <ImageFile: 08-NYH-GS-EBJ--21-of-33.jpg>, <ImageFile: 08-NYH-GS-EBJ--2-of-33.jpg>, <ImageFile: 11-NYH-Stale-Wig-deep-reading-EBJ--9-of-13.jpg>, <ImageFile: 08-NYH-GS-EBJ--3-of-33.jpg>, '...(remaining elements truncated)...']>

# %%
def get_contributor(image_file):
    name, contributor = None, None
    if image_file.contributor:
        contributor = image_file.contributor
        logger.debug('was assigned')
        return contributor
    if image_file.exif:
        exif = image_file.exif
        names = [exif.artist, re_find(r'[fF]oto:(.*)^', exif.description)]
        name = sorted(names, key=len)[-1]
    if name and not contributor:
        try:
            contributor = Contributor.objects.get(display_name=name)
            logger.debug(f'found name {name}')
        except Contributor.DoesNotExist:
            matches = Contributor.objects.search(name)
            if matches.count() == 1:
                contributor = matches[0]
                logger.debug(f'fuzzy search for name {name} -> {contributor}')
    initials = get_initials_from_file_name(image_file.original.name)
    if initials and not contributor:
        try:
            contributor = active_photographers(when=image_file.created).get(initials=initials)
            logger.debug(f'found initials {initials}')
        except Contributor.DoesNotExist:
            contributor = lookup.get(initials) 
                
    if not contributor:
        sim = image_file.storyimage_set.first()
        if sim:
            photo_byline = sim.parent_story.byline_set.filter(credit='photo')
            if photo_byline.count() == 1:
                contributor = photo_byline.first().contributor
                logger.debug(f'found photo byline {photo_byline.first()}')
    
    if not contributor and (name or initials):
        logger.warn(f'{image_file} did not find {name} / {initials}')
    return contributor

def assign_contributor(qs):
    disconnect_signals()
    success = []
    fail = []
    for im in qs:
        cn = get_contributor(im)
        if cn:
            im.contributor = cn
            im.category = ImageFile.PHOTO
            im.save()
            success.append(f'{im.pk:<5} {str(cn):<40} {im}')
        else:
            fail.append(str(im))
    print('OK:')
    print('\n'.join(success))
    print('\nFAIL:')
    print('\n'.join(fail))
        
qs = ImageFile.objects.filter(contributor=None).order_by('?')
print(qs.count())

assign_contributor(qs.filter(source_file__contains='PP'))
# Out:
# 10830
# OK:
# 31453 Paul Patrick Børhaug                     23-NYH-nyhmiljopart-05-PP.jpg
# 31511 Paul Patrick Børhaug                     23-NYH-nyhvalg-04-PP.jpg
# 31569 Paul Patrick Børhaug                     24-NYH-nyh245paplas-03-PP.jpg
# 31571 Paul Patrick Børhaug                     24-NYH-nyh245paplas-05-PP.jpg
# 31588 Paul Patrick Børhaug                     24-NYH-nyh245paplas-04-PP_7KvDKYz.jpg
# 31508 Paul Patrick Børhaug                     23-NYH-nyhvalg-01-PP.jpg
# 31450 Paul Patrick Børhaug                     23-NYH-nyhmiljopart-03-PP.jpg
# 31516 Paul Patrick Børhaug                     23-NYH-nyhvalg-09-PP.jpg
# 31515 Paul Patrick Børhaug                     23-NYH-nyhvalg-08-PP.jpg
# 31512 Paul Patrick Børhaug                     23-NYH-nyhvalg-05-PP.jpg
# 31533 Paul Patrick Børhaug                     23-NYH-nyhvalg-08-PP_JcAsIzQ.jpg
# 31570 Paul Patrick Børhaug                     24-NYH-nyh245paplas-04-PP.jpg
# 22233 Paul Patrick Børhaug                     22-plakkate-01-PP.jpg
# 31514 Paul Patrick Børhaug                     23-NYH-nyhvalg-07-PP.jpg
# 31448 Paul Patrick Børhaug                     23-NYH-nyhmiljopart-01-PP.jpg
# 31566 Paul Patrick Børhaug                     24-KUL-kulallwhitep-03-PP.jpg
# 31568 Paul Patrick Børhaug                     24-NYH-nyh245paplas-02-PP.jpg
# 31513 Paul Patrick Børhaug                     23-NYH-nyhvalg-06-PP.jpg
# 31567 Paul Patrick Børhaug                     24-NYH-nyh245paplas-01-PP.jpg
#
# FAIL:
# NAPP-26-07-9.jpg
# NAPP-24-6-7.jpg
# NAPP-6-6-1.jpg
# 16-NYH-DalaiLama-PPS-11.jpg
# 01-PPS-KUL-Ludviglewin-01.JPG
# PPgVKUr-400x400.jpg
# NAPP-26-7-1.jpg
# NAPP-26-07-7.jpg
# NAPP-26-07-12.jpg
# 21-grunnlovsboka-CAPPELEN.jpg
# NAPP-24-6-1.jpg

# %%
from collections import Counter
qs = ImageFile.objects.filter(contributor=None)
filenames = list(qs.values_list('source_file', flat=True))
counter = Counter([get_initials_from_file_name(fn) for fn in filenames])
counter.pop('')

def get_contrib(images):
    pks = images.values_list('contributor', flat=True)
    return Contributor.objects.filter(pk__in=pks)

for initials, cnt in counter.most_common(100):
    cn = active_photographers().filter(initials=initials)
    #print(cnt, initials, list(cn))
    if cn.count() == 0:
        print('no', initials, cnt)
        images = ImageFile.objects.exclude(contributor=None).filter(source_file__contains=initials)
        for im in images:
            who = []
            if get_initials_from_file_name(str(im.source_file)) == initials:
                who.append(str(im.contributor))
        print(Counter(who))
            
        
    if cn.count() == 1:
        cn = cn[0]
        update = []
        for im in qs.filter(source_file__contains=initials):
            if get_contributor(im) == cn:
                update.append(im.pk)
        ImageFile.objects.filter(pk__in=update).update(contributor=cn)
        print(update, cn)
# Out:
# no UK 50
# Counter()
# no XX 31
# Counter()
# no XTERN 28
# Counter({'Helle Gannestad': 1})
# no MG 23
# Counter()
# no ARKIV 22
# Counter()
# no ASB 20
# Counter()
# no PP 19
# Counter()
# no AKM 12
# Counter()
# no VIB 10
# Counter()
# no AG 10
# Counter()
# no PRIVATE 8
# Counter()
# no AKH 8
# Counter()
# no IA 8
# Counter()
# no A 7
# Counter()
# no CC 7
# Counter()
# no OBE 7
# Counter()
# no Q 6
# Counter()
# no NY 6
# Counter()
# no AF 6
# Counter()
# no EXT 6
# Counter()
# no AHO 5
# Counter()
# no PS 5
# Counter()
# no HDR 5
# Counter()
# no IMG 5
# Counter()
# no BI 4
# Counter()
# no ARK 4
# Counter()
# no OLN 4
# Counter()
# no IG 4
# Counter()
# no KAO 4
# Counter()
# no IH 3
# Counter()
# no BHK 3
# Counter()
# no K 3
# Counter()
# no WEB 3
# Counter()
# no MKH 3
# Counter({'Morten Harnang': 1})
# no COVER 3
# Counter()
# no AABE 3
# Counter({'Richard Eriksen': 1})
# no LP 3
# Counter()
# no PLAGIATARK 3
# Counter()
# no AGS 3
# Counter()
# no DSC 3
# Counter()
# no LRL 2
# Counter({'Liv Rønnaug Bjerke Lilleåsen': 1})
# no AUHA 2
# Counter({'Aurora Hannisdal': 1})
# no SIGNE 2
# Counter({'Aurora Hannisdal': 1})
# no WC 2
# Counter({'Aurora Hannisdal': 1})
# no ETR 2
# Counter({'Aurora Hannisdal': 1})
# no CMYK 2
# Counter()
# no ED 2
# Counter()
# no DNS 2
# Counter()
# no MN 2
# Counter()
# no SM 2
# Counter()
# no SCAN 2
# Counter()
# no JVL 2
# Counter()
# no EIR 2
# Counter()
# no OKK 2
# Counter()
# no TILBAKE 2
# Counter()
# no AT 2
# Counter()
# no STOR 2
# Counter()
# no HOY 2
# Counter()
# no ARTHAUS 2
# Counter()
# no FRP 2
# Counter()
# no ANK 2
# Counter({'Anders Nordmo Kvammen': 1})
# no ALB 2
# Counter({'Anders Nordmo Kvammen': 1})
# no MEH 2
# Counter({'Nordis Tennes': 1})
# no FF 2
# Counter()
# no TCT 2
# Counter()
# no NOTAM 2
# Counter()
# no SAIH 2
# Counter()
# no NSO 2
# Counter({'Øyvind Aukrust': 1})
# no UMB 2
# Counter({'Øyvind Aukrust': 1})
# no XXX 2
# Counter({'Øyvind Aukrust': 1})
# no NRK 2
# Counter({'Brian Olguin': 1})
# no GGAADD 2
# Counter({'Brian Olguin': 1})
# no BM 2
# Counter({'Birte Nystad Magnussen': 1})
# no UD 2
# Counter()
# no AURORAHANNISDAL 2
# Counter({'Aurora Hannisdal': 1})
# no ANDERS 2
# Counter({'Aurora Hannisdal': 1})
# no DNB 2
# Counter({'Aurora Hannisdal': 1})
# no AL 2
# Counter()
# no O 2
# Counter()
# no EF 2
# Counter({'Skjalg Bøhmer Vold': 1})
# no TST 1
# Counter({'Skjalg Bøhmer Vold': 1})
# no AID 1
# Counter({'Skjalg Bøhmer Vold': 1})
# no LARS 1
# Counter({'Skjalg Bøhmer Vold': 1})
# no KOMMENTAR 1
# Counter({'Skjalg Bøhmer Vold': 1})
# no BESLAN 1
# Counter({'Skjalg Bøhmer Vold': 1})
# no FM 1
# Counter({'Skjalg Bøhmer Vold': 1})
# no CLEMET 1
# Counter()
# no KR 1
# Counter()
# no P 1
# Counter()
# no KDA 1
# Counter()
# no GWEN 1
# Counter()
# no HUSTAD 1
# Counter()
# no HF 1
# Counter()
# no AMG 1
# Counter()
# no VEL 1
# Counter()
# no C 1
# Counter()
# no MANGLER 1
# Counter()
# no TOOE 1
# Counter()
# no GON 1
# Counter({'Marius N. Pettersen': 1})
# no FORFATTER 1
# Counter({'Marius N. Pettersen': 1})

# %%
# Kvammen Illustrasjoner
ImageFile.objects.filter(source_file__contains='-ANK.jpg').update(category=ImageFile.ILLUSTRATION, contributor=kvammen)
# Out:
# 80

# %%
for im in ImageFile.objects.filter(source_file__contains='doveog'):
    print(im.storyimage_set.first().parent_story)
# Out:
# 2016-02-23: Kritikk for døve ører
# 2016-02-23: Kritikk for døve ører
# 2016-02-23: Kritikk for døve ører
# 2016-02-23: Kritikk for døve ører
# 2016-02-23: Kritikk for døve ører
# 2016-02-23: Kritikk for døve ører
# 2016-02-23: Kritikk for døve ører
# 2016-02-23: Kritikk for døve ører

# %%
for bl in Byline.objects.exclude(title=None).exclude(title='').filter(credit='photo'):
    print(bl)
# Out:
# @bl: Foto: Maria Reinertsen, Hilde Raa
# @bl: Foto: Henrik Evertsson, fotograf i Universitas
# @bl: Foto: Jostein Sand Nilsen, Håkon Mosvold
# @bl: Foto: Halvor Finess Tretvoll, Håkon Rasmus Bergseth
# @bl: Foto: Halvor Finess Tretvoll, Håkon Rasmus Bergseth
# @bl: Foto: Halvor Finess Tretvoll, Håkon Rasmus Bergseth
# @bl: Foto: Pål Hovengen Plassen, Åshild Støylen
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erik Møller Solheim, Fredrik Arff
# @bl: Foto: Erik Møller Solheim, Fredrik Arff
# @bl: Foto: Espen Gleditsch, Ellinor Bent Dalbye
# @bl: Foto: Espen Gleditsch, Iván Kverme
# @bl: Foto: Audun Kolstad Wiig, Ellinor Bent Dalbye
# @bl: Foto: Anne Bergitte Viken, Camilla Tully
# @bl: Foto: Svein Egil Hatlevik, Ellen Svendsen, Ingjerd Sørlie
# @bl: Foto: Ida Marie Jahr, Kristian Ridder–Nielsen
# @bl: Foto: Michael Brøndbo, Kristian Ridder–Nielsen
# @bl: Foto: Ida Marie Jahr, Ivàn Kverme
# @bl: Foto: Anne Bergitte Viken, Ingjerd Sørlie
# @bl: Foto: Anne Bergitte Viken, Ida Marie Jahr, Iván Kverme
# @bl: Foto: Anne Bergitte Viken, Iván Kverme
# @bl: Foto: Anne Bergitte Viken, Ivàn Kverme
# @bl: Foto: Tonje Eliasson, Hanne O. Hvattum
# @bl: Foto: Marianne Knarud Sagen, Åshild Bekke Eidem
# @bl: Foto: Eivind Sørlie, Kristin Fredriksen, Silje Eide
# @bl: Foto: Åshild Bekke Eidem, Vårt Land
# @bl: Foto: Matthis Kleeb Solheim, Fotograf
# @bl: Foto: Odin Jæger, Fotograf
# @bl: Foto: Håkon Benjaminsen, Fotograf
# @bl: Foto: Journalist I Universitas, Raisa Porsanger
# @bl: Foto: Amanda O. Berg, Fotosjef i Universitas
# @bl: Foto: Melisa Fajkovic, Øyvind Aukrust
# @bl: Foto: Henriette Dæhli,
# @bl: Foto: Patrick da Silva Sæther, alle foto
# @bl: Foto: Amanda O. Berg, Fotosjef i Universitas
# @bl: Foto: Amanda O. Berg, Fotosjef i Universitas
# @bl: Foto: Dorthe Karlsen, Fotojournalist i USA
# @bl: Foto: Dorthe Karlsen, fotograf i USA
# @bl: Foto: Dorthe Karlsen, Fotograf i USA
# @bl: Foto: Adrian Nielsen, Fotograf i Universitas
# @bl: Foto: Adrian Nielsen, Fotograf i Universitas
# @bl: Foto: Benedicte Elisabeth Bjerknes, Adrian Nielsen
# @bl: Foto: Christoffer Gundersen, Helle Gannestad
# @bl: Foto: Stine Stenhaug, Eskil Wie
# @bl: Foto: Astrid Karstensen, Helle Gannestad
# @bl: Foto: Petter Fløttum, Eskil Wie
# @bl: Foto: Benedicte Elisabeth Bjerknes, Eskil Wie
# @bl: Foto: Anders Sundstøl Bjørkheim, Petter Fløttum, Henrik Evertsson
# @bl: Foto: Marit M. Simonsen, Eskil Wie
# @bl: Foto: Magnus Newth, Helle Gannestad
# @bl: Foto: Geir Molnes, Petter Fløttum, Ena Kreso
# @bl: Foto: Geir Molnes, Henrik Evertsson
# @bl: Foto: Kristin Antonsen Brenna, Hans Dalane-Hval
# @bl: Foto: Eskil Wie, Eskil Wie
# @bl: Foto: Stine Stenhaug, Helle Gannestad
# @bl: Foto: Martine Engebretsen Li, Helle Gannestad
# @bl: Foto: Martine Engebretsen Li, Thorbjørn K. Borlaug
# @bl: Foto: Martine Engebretsen Li, Thorbjørn Kringlebotn Borlaug
# @bl: Foto: Thea Storøy Elnan, Helle Gannestad
# @bl: Foto: Thorbjørn Kringlebotn Borlaug, Geir Molnes, Peter Tryggestad, Helle Gannestad
# @bl: Foto: Kristin Antonsen Brenna, Ena Kreso
# @bl: Foto: Kenneth Wangen, Henrik Evertsson
# @bl: Foto: Petter Fløttum, Ena Kreso
# @bl: Foto: Aili Røtterud Løchen, Helle Gannestad
# @bl: Foto: Jenny Gudmundsen, Henrik Evertsson
# @bl: Foto: Kristina Elisabet Kvammen, Magasinfotosjef i Universitas
# @bl: Foto: Øyvind Aukrust, Fotograf
# @bl: Foto: Dorthe Karlsen, Fotograf
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Signe Rosenlund-Hauglid, magasinredaktør i Universitas, Adrian Nielsen
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Erlend Dalhaug Daae, Photo Editor
# @bl: Foto: Erlend Dalhaug Daae, Photo Editor
# @bl: Foto: Kristina Elisabet Kvammen, Magasinfotosjef
# @bl: Foto: Hanna Hjardar, Magasinfotosjef
# @bl: Foto: Erlend Dalhaug Daae, Fotosjef
# @bl: Foto: Hanna Hjardar, Fotograf i Russland

# %%
aaah = Contributor.objects.get(display_name__startswith='Anders Aavik Hagen')
ImageFile.objects.filter(contributor=None, source_file__contains='AAAH').update(contributor=aaah)

# %%
for im in ImageFile.objects.order_by('?')[:100]:
    initials = get_initials_from_file_name(im.original.name)
    print(f'{initials:<5} {im.original.name}')

# %%
llif = ImageFile.objects.filter(source_file__contains='LLIF')
nr = ImageFile.objects.filter(source_file__contains='NR')
print(nr)
ImageFile.objects.filter(source_file__contains='_')

# %%
for im in llif:
    print(im.exif)

# %% [markdown]
# # Byline Images

# %%
# categorize
ImageFile.objects.filter(source_file__startswith='byline-photo').update(category=ImageFile.PROFILE)

# %%
# find possible misspelled names
from collections import Counter
cnn = Contributor.objects.extra(where=["CHAR_LENGTH(aliases) > 20"])
for cn in cnn:
    aliases = Counter(cn.aliases.strip().split('\n'))
    aliases = (f'"{k}" ({v}),' for k, v in aliases.items() if v > 1)
    print(f'"{cn}": {"|".join(aliases)}')
# Out:
# "Studentmållaget I Oslo":
# "Conflict Studies)":
# "Det Norske Studentersamfund":
# "NN": "Paul Patrick Borhaug" (2),
# "Christina Bock Bjørn–Hansen":
# "Universitas’ Matpanel. Foto: Ketil Blom":
# "Akademikernes Internasjonale Hjelpefond)":
# "Melike Leblebicio?Lu Ketil Blom":

# %%
fix = {
    " Prof. Ingrid Os": "Ingrid Os",
    ". Translated By Michael Brøndbo": "Michael Brøndbo",
    "Adrian Nielsen": "Adrian Nielsen",
    "Adrian Simen Holm": "Adrian Simen Holm",
    "Aksel Schreiner Brakestad": "Aksel Schreiner Brakestad",
    "Aleksander Myklebust": "Aleksander Myklebust",
    "Alf Grønli Simensen": "Alf Simensen",
    "Amanda O. Berg": "Amanda O. Berg",
    "Anders Aa. Hagen": "Anders Aavik Hagen",
    "Anders Imenes": "Anders Gravir Imenes",
    "Anders Jupskås": "Anders Ravik Jupskås",
    "Anders Nordmo Kvammen": "Anders Nordmo Kvammen",
    "Anders R. Christensen": "Anders R. Christensen",
    "Anders Schiøtz Worren": "Anders Schiøtz Worren",
    "Anders Sundstøl Bjørkheim": "Anders Sundstøl Bjørkheim",
    "Anders Veberg": "Anders Veberg",
    "Andreas Slørdahl": "Andreas Slørdahl",
    "Andreas Øien Stensland": "Andreas Øien Stensland",
    "André Larsen Avelin": "André Larsen Avelin",
    "Angelique Culvin": "Angelique Culvin",
    "Anja Kristine Salo": "Anja Kristine Salo",
    "Anne B. Viken": "Anne Bergitte Viken",
    "Anne Fougner Helseth": "Anne Fougner Helseth",
    "Anne Leifsdatter Grønlund": "Anne Leifsdatter Grønlund",
    "Are W. Sandvik": "Are Westerink Sandvik",
    "Aslak Johannessen": "Aslak Johannesen",
    "Aud V. Tønnessen": "Aud V. Tønnessen",
    "Aud Valborg Tønnesen": "Aud Valborg Tønnesen",
    "August Tekrø": "August Tekrø",
    "Aurora Sæverud": "Aurora Sæverud",
    "Axel Geard Nygaard": "Axel Geard Nygaard",
    "Axel M. K. Hærland": "Axel Munthe-Kaas Hærland",
    "Bendik Baksaas": "Bendik Baksaas",
    "Benedicte Tandsæther-Andersen": "Benedicte Tandsæther-Andersen",
    "Benjamin Endré Larsen": "Benjamin Endré Larsen",
    "Benjamin Oliver": "Benjamin Edward Oliver",
    "Birgit Skarstein": "Birgit Røkkum Skarstein",
    "Birte Nystad Magnussen": "Birte Nystad Magnussen",
    "Bjarne Henning Kvåle": "Bjarne Henning Kvaale",
    "Bjørnar K. Bekkevard": "Bjørnar Konglevoll Bekkevard",
    "Bjørn–Egil Mikalsen": "Bjørn-Egil Mikalsen",
    "Brage Herlofsen": "Brage Herlofsen",
    "Brian Olguin": "Brian Olguin",
    "Brita Søreng": "Brita Melissa Botnen Søreng",
    "Camilla Brønnich Eikeland": "Camilla Brønnich Eikeland",
    "Carina I. Hunshamar": "Carina Isabelle Hunshamar",
    "Cecilie Einarson Pérez": "Cecilie Einarson Pérez",
    "Christian Lycke": "Christian Lyche",
    "Christina Bock Bjørn-Hansen": "Christina Bock Bjørn–Hansen",
    "Christina Bock": "Christina Bock",
    "Christine Skogen Nyhagen": "Christine Skogen Nyhagen",
    "Daniel Heggelid-Rugaas": "Daniel Heggelid-Rugaas",
    "Eirik B. Traavik": "Eirik B. Traavik",
    "Eirik Billingsø Elvevold": "Eirik Billingsø Elvevold",
    "Elisabeth Rørbakk Jakobsen": "Elisabeth Rørbakk Jakobsen",
    "Elisabeth Torkildsen": "Elisabeth Torkildsen",
    "Ellen Munden Paalgard": "Ellen Munden Paalgard",
    "Ellen Paalgaard": "Ellen Munden Paalgaard",
    "Ellinor Bente Dalbye": "Ellinor Bent Dalbye",
    "Embret T. Rognerød": "Embret T. Rognerød",
    "Emilie Solberg": "Emilie Solberg",
    "Erika Kristine Ribu": "Erika Kristine Ribu",
    "Erling Hillestad": "Erling G. Hillestad",
    "Eva–Kristin Urestad Pedersen": "Eva-Kristin Urestad Pedersen",
    "Evelyn Pecori": "Evelyn Pecori",
    "Foto Angélique Culvin": "Angélique Culvin",
    "Frederick Alexander Reiersen": "Frederick Alexander Reiersen",
    "Gaute M. Kornberg": "Gaute M. Kornberg",
    "Grethe Kielland-Jenssen": "Grethe Kielland-Jenssen",
    "Gunhild Oland Nedrelid": "Gunhild Oland Nedrelid",
    "Haakon Jamtli Kristiansen": "Haakon Jamtli Kristiansen",
    "Hallvard Østtveit Barbogen": "Hallvard Østtveit Barbogen",
    "Halvor Finess Tretvoll": "Halvor Finess Tretvoll",
    "Hanna Kristin Hjardar": "Hanna Kristin Hjardar",
    "Hanna Magnussen Krogvold": "Hanna Magnussen Krogvold",
    "Hanna Skotheim": "Hanna Skotheim",
    "Hanne Hvattum": "Hanne O. Hvattum",
    "Hanne Marie Lenth Solbø": "Hanne Marie Lenth Solbø",
    "Hans Dalane-Hval": "Hans Dalane-Hval",
    "Hans J. Skjong": "Hans Joseph Skjong",
    "Harald Fagerheim Bugge": "Harald Fagerheim Bugge",
    "Hedvig Mollestad Thomassen": "Hedvig Mollestad Thomassen",
    "Heidi T. Harto": "Heidi Thaulow Harto",
    "Helena Nielsen": "Helena Nielsen",
    "Helene Kristensen": "Helene Kristiansen",
    "Hilde Berteig Rustan": "Hilde Berteig Rustan",
    "Håkon Borgos": "Håkon Borgos",
    "Håkon Frede Foss": "Håkon Frede Foss",
    "Ida Elizabeth Torp Halvorsen": "Ida Elizabeth Torp Halvorsen",
    "Ida Lyngstad Wernø": "Ida Lyngstad Wernø",
    "Ida Madsen Hestman": "Ida Madsen Hestman",
    "Igor Nilsen": "Igor R. Nilsen",
    "Ine Eriksen Søreide": "Ine Eriksen Søreide",
    "Ingeborg Huse Amundsen": "Ingeborg Huse Amundsen",
    "Ingeborg Marie Østby Laukvik (Leder": "Ingeborg Marie Østby Laukvik",
    "Ingeborg Skjelkvåle Ligaarden": "Ingeborg Skjelkvåle Ligaarden",
    "Ingjerd Sørlie": "Ingjerd Sørli",
    "Ingri Bergo": "Ingri G. Bergo",
    "Ingrid Aune": "Ingrid Aune",
    "Ingrid Eidsheim Daae": "Ingrid E. Daae",
    "Ingrid Elise Gipling": "Ingrid Gipling",
    "Ingrid H. F. Brubaker": "Ingrid Flognfeldt Brubaker",
    "Ingrid K. Fredriksen": "Ingrid Kvamme Fredriksen",
    "Ingrid N. Ekeberg": "Ingrid N. Ekeberg",
    "Ingrid Stranger–Thorsen": "Ingrid Stranger-Thorsen", 
    "Ingvild S. Reymert": "Ingvild S. Reymert",
    "Iselin Rud–Goksøyr": "Iselin Rud-Goksøyr",
    "Iselin Shaw of Tordarroch": "Iselin Shaw of Tordarroch",
    "Iván Kverme": "Ivàn Kverme",
    "Jamal Mohsin Masterstudent": "Jamal Mohsin",
    "Jan Thomas Holmlund": "Jan Thomas Holmlund",
    "Janni Kalafatis": "Janni Frederiksen Kalafatis",
    "Jens Å. R. Haga": "Jens Ådne R. Haga",
    "Joakim P. Berg": "Joakim P. Berg",
    "Julianne B. Mossing": "Julianne B. Mossing",
    "Julie Kalager": "Julie Kalager",
    "Julie Nordby Egeland": "Julie Nordby Egeland",
    "Julie Paus-Knudsen": "Julie Sørlie Paus-Knudsen",
    "June Torgersen": "June Marie Torgersen",
    "Jørgen Brynhildsvoll": "Jørgen Brynhildsvoll",
    "Jørn Wiche Pedersen": "Jørn Wichne Pedersen",
    "Kaj M. Duesund": "Kaj M. Duesund",
    "Kamilla Simonnes": "Kamilla Simonnes",
    "Karl Kristian Rådahl Kirchhoff": "Karl Kristian Rådahl Kirchhoff",
    "Katarina A. Rodina": "Katarina A. Rodina",
    "Katrine Elida Aaland": "Katrine Elida Aaland",
    "Ketil Blom": "Ketil Blom",
    "Kim Kantardjiev": "Kim Orlin Kantardjiev",
    "Kim Michael G. G. Thon": "Kim Michael G. G. Thon",
    "Kristian Ridder–Nielsen": "Kristian Ridder-Nilsen",
    "Kristin Jonassen Nordby": "Kristin Nordby",
    "Kristin Pettersen": "Kristin Pettersen",
    "Kristina Klakegg": "Kristina Klakegg",
    "Kristina Kvammen": "Kristina Elisabet Kvammen",
    "Kristoffer Hatteland Endresen": "Kristoffer Hatteland Endresen",
    "Lars Eng Førde": "Lars Engh Førde",
    "Lars-Christian U. Talseth": "Lars-Christian U. Talseth",
    "Leif Martin Kirknes": "Leif Martin Kirknes",
    "Lene C. Westgaard": "Lene C. Westgaard",
    "Lene Christensen": "Lene Christensen",
    "Lilly Susanne Stensland": "Susanne Stensland",
    "Line Ørnes Søndergaard": "Line Ørnes Søndergaard",
    "Lise Falck": "Lise Falch",
    "Lise Marie Danielsen": "Lise Marie Danielsen",
    "Liv Rønnaug Lilleåsen": "Liv Rønnaug Bjerke Lilleåsen",
    "Liv-Kristin Rød Korssjøen": "Liv-Kristin Rød Korssjøen",
    "Magnus Ekeland": "Magnus Ekeland",
    "Magnus K. Worren": "Magnus K. Worren",
    "Malene Hoftun Jæger": "Malene Hoftun Jæger",
    "Maren Blaalid": "Maren Blaalid",
    "Mari Helén Varøy Mari Mamre": "Mari Mamre",
    "Mari K. S. Gjelstad": "Mari K. S. Gjelstad",
    "Mari Lund Haanshus": "Mari Lund Haanshus",
    "Maria Reinertsen": "Maria Reinertsen",
    "Maria T. Pettrém": "Maria T. Pettrém",
    "Maria Terese Kittilsen": "Maria Terese Kittilsen",
    "Maria Terray Brantenberg": "Maria Terray Brantenberg",
    "Marianne Granheim Trøyflat": "Marianne Granheim Trøyflat",
    "Marianne Høva Rustberggard": "Marianne Høva Rustberggard",
    "Marianne Johansen": "Maria Mår Johansen",
    "Marit Aasmo Albrigtsen": "Marit Aasmoe Albrigtsen",
    "Marit Austvik Letnes": "Marit Austvik Letnes",
    "Marit M. Simonsen": "Marit M. Simonsen",
    "Marit Sunnanå Aalrust": "Marit Sunnanå Aalrust",
    "Marius Nergård Pettersen": "Marius N. Pettersen",
    "Marte B. L. Torskenæs": "Marte Lia Torskenæs",
    "Marte Engehaugen Bøhm": "Marte Engehaugen Bøhm",
    "Marthe Amanda Vannebo": "Marthe Amanda Vannebo",
    "Martin Anders Dahl": "Martin Anders Dahl",
    "Mats Kirkebirkeland": "Mats Kirkebirkeland",
    "Mats Sivertsen": "Mats Sivertsen",
    "Matthis Kleeb Solheim": "Matthis Kleeb Solheim",
    "Melike Leblebicioğlu": "Melike Leblebicioğlu",
    "Mirjam K. S. Folkvord": "Mirjam Sorge Folkvord",
    "Morten Oftedal Schwencke": "Morten Schwencke",
    "Nicolay Woldsdal": "Nicolay Woldsdal",
    "Nora Nygaard": "Nora Nygaard",
    "Ola Magnusson Rydje": "Ola Magnussen Rydje",
    "Patrick da Silva Sæther": "Patrick da Silva Sæther",
    "Paul Anthony Wilson": "Paul Anthony Wilson",
    "Paul Patrick Børhaug": "Paul Patrick Børhaug",
    "Peder Stabell": "Peder D. Stabell",
    "Per Anders Torvik Langerød": "Per Anders Langerød",
    "Petter Drange Brønstad": "Petter Brønstad",
    "Petter Risøe": "Petter Risøe",
    "Philip André Johannesborg": "Philip André Johannesborg",
    "Pia Sandved Berg": "Pia Sandved Berg",
    "Pål Vegard R. Hagesæther": "Pål Vegard Rameckers Hagesæther",
    "Rachel Elisabeth Antonsen": "Rachel Elisabeth Antonsen",
    "Ragnhild Eline Hoen": "Ragnhild Eline Hoen",
    "Regine Stokstad": "Regine Stokstad",
    "Robin Røkke Johansen": "Robin Røkke Johansen",
    "Rolv Christian Topdahl": "Rolv Christian Topdahl",
    "Runa Fjellanger": "Runa Fjellanger",
    "Runar B. Mæland": "Runar Bjørkvik Mæland", 
    "Sebastian Dahl": "Sébastian Dahl",
    "Sebastian Wemmerløv": "Sebastian Wemmerløv",
    "Signe Bakke Johannessen": "Signe Bakke Johannessen",
    "Sigurd Arnekleiv Bækkelund": "Sigurd Arnekleiv Bækkelund",
    "Sigurd K Berg": "Sigurd K. Berg",
    "Sigurd Oland Nedrelid": "Sigurd Oland Nedrelid",
    "Siri Øverland Eriksen": "Siri Øverland Eriksen",
    "Sjur Stølen": "Sjur Stølen",
    "Solveig Figenschou": "Solveig Figenschou",
    "Solveig Nygaard Langvad": "Solveig N. Langvad",
    "Solveig Schanke Eikum": "Solveig Schanke Eikum",
    "Sondre Myhre": "Sondre Moen Myhre",
    "Steffen S. Aagedal": "Steffen S. Aagedal",
    "Stella Heieren": "Stella Heieren",
    "Sten Ånnerud": "Sten J. Mcneil Ånnerud",
    "Stig Siversten": "Stig Siversten",
    "Stine G. Bergo": "Stine G. Bergo",
    "Studentparlamenett Uio": "Studentparlamentet Uio",
    "Stéphane Lelarge": "Stéphane Lelarge",
    "Sunniva R. Skjeggestad": "Sunniva R. Skjeggestad",
    "Tea Grav Rosenberg": "Thea Grav Rosenberg",
    "Thea Finstad": "Thea Nathalie Finstad",
    "Thea Urdal": "Thea Håmo Urdal",
    "Thomas A Syvertsen": "Thomas André Syvertsen",
    "Thorbjørn Kringlebotn Borlaug": "Thorbjørn Kringlebotn Borlaug",
    "Thorbjørn Kringlebotn": "Thorbjørn Kringlebotn",
    "Tia Karlsen": "Tia Kristine Karlsen",
    "Tone C. S. Thorgrimsen": "Tone Celine Sundseth Thorgrimsen",
    "Tonje T. Larsen": "Tonje T. Larsen",
    "Tonje Thielsen": "Tonje Thilesen",
    "Torbjørn S. Holen": "Torbjørn Sundal Holen",
    "Torgeir Mortensen": "Torgeir Mortensen",
    "Translation By Ingrid F. Brubaker": "Ingrid F. Brubaker",
    "Universitas´ Juleølpanel": "Universitas´ Juleølpanel",
    "Universitas’ Sommerøltestpanel": "Universitas’ Sommerøltestpanel",
    "Unni Claussen": "Unni Claussen",
    "Vegard Kristiansen Kvaale": "Vegard Kristiansen Kvaale",
    "Victor Andreas Shammas": "Victor Lund Shammas",
    "Vida Sundseth Brenna": "Vida Sundseth Brenna",
    "Vilde G. Larsen": "Vilde Grønn Larsen",
    "Vilde Sagstad Imeland": "Vilde Sagstad Imeland",
    "Wanda Nordstrøm": "Wanda Nathalie Nordstrøm",
    "Wenche Åsheim": "Wenche D. Åsheim",
    "Åshild Støylen": "Åshild Støylen",
    "Åsmund Øvsthus": "Åsmund P. Øvsthus",
    "Øistein Ø. Svelle": "Øistein Ø. Svelle",
    "Øyvind Østerås": "Øyvind Østerås",
}

# %%
cnn = Contributor.objects.extra(where=["CHAR_LENGTH(aliases) > 20"])
for cn in cnn:
    name = cn.display_name
    if name in fix:
        cn.display_name = fix[name]
        cn.aliases = ''
        print(f'{name:<30} -> {cn.display_name}')
        cn.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-e87b3a2ac4fe> in <module>()
#       2 for cn in cnn:
#       3     name = cn.display_name
# ----> 4     if name in fix:
#       5         cn.display_name = fix[name]
#       6         cn.aliases = ''
#
# NameError: name 'fix' is not defined

# %%
# Disse to personenen er forskjellige
{"Helena Nielsen": "Lena Nielsen"}
helena = Contributor.objects.get(display_name='Helena Nielsen')
lena = Contributor.objects.get_or_create(display_name='Lena Nielsen')[0]
helena.byline_set.filter(credit='photo').update(contributor=lena)

# %%
# Update photographer initials
def get_initials(name):
    name = name.translate(str.maketrans('ÆØÅ', 'AOA'))
    return ''.join(re.findall(r'[A-Z]', name))[:5]

def is_photographer(cn):
    if cn.stint_set.filter(position__title='fotograf').count():
        return True
    if cn.byline_set.filter(title='foto').count():
        return True
    if cn.imagefile_set.count():
        return True
    else:
        return False
    
    
for cn in Contributor.objects.all().order_by('display_name'):
    if is_photographer(cn):
        initials = get_initials(str(cn))
        if cn.initials != initials:
            cn.initials = initials
            cn.save() 
        print(f'{str(cn.initials):<6} {name:<30} {cn.user or "-"}')
    elif cn.initials:
        cn.initials = ''
        cn.save() 
    name = str(cn)
# Out:
# NN     Thomas L. Myhrvold–Hanssen Cand. Philol -
# NN     NN                             -
# AN     Ådne Hindenes                  -
# AKV    Aksel Hagen                    -
# AM     Aleksander Martin Gjøsæter     -
# AQG    Alexander Løtvedt              -
# AS     Alf Jensen                     -
# ABP    Amalie Rossland Christiansen   -
# AOB    Amanda Borch Pacheco           -
# AO     Amina Storm                    -
# AA     Amund Trellevik                -
# AAH    Anders Aasbø                   -
# AFL    Anders C. Heli                 -
# AR     Anders R. Christensen          -
# AV     Anders Sundstøl Bjørkheim      -
# AN     Andreas Nebdal                 -
# AC     Anette Remme                   -
# AW     Anna Vibeke Lorentzen          -
# ABV    Anna Young                     -
# ALG    Anne Kathrine Wexels Wold      -
# AO     Anne Nordheim                  -
# A      Arild Underdal                 -
# AH     Asbjørn Slettemark             -
# ABE    Åse Michaelsen                 -
# AS     Åshild Lappegård Lahn          -
# AJ     Asjad Mahmood                  -
# AK     Astrid Hovde                   -
# AS     Astrid Mjærum                  -
# AH     Audun Automat                  -
# AKW    Audun Halaas                   -
# AH     Aurora B                       -
# AMKH   Axel M.K Hærland Tegneseriebibel -
# BL     Bendik Hellem Aaby             -
# BEB    Bendik Løve                    -
# BS     Benedicte Westlund             -
# BA     Bent Johan Mosfjell            -
# BNM    Birte Magnusson                -
# BKB    Bjørnar A. Eilertsen           -
# BB     Bjørn Boysen                   -
# BO     Brage Herlofsen                -
# BMBS   Brian Olguin                   -
# CAL    Burleben                       camilla
# CT     Camilla Svendsen Skriung       -
# CB     Christian Anton Smedshaug      -
# CL     Christian Lomsdalen            -
# CE     Christina Teige Apuzzo         -
# CK     Christine Erlbeck              -
# DC     Dag Vemund Haanæs              -
# DV     David Persson                  -
# DK     Doris Jorde                    -
# DKOMK  Dorthe Karlsen                 -
# EBJ    Eirik Braathen                 -
# ET     Eirin Nordal                   -
# ETIRN  Eir Torvik                     -
# EM     Eivind Løvaas                  -
# ES     Eivind Solfjell                -
# EJ     Elisabeth Holien               -
# ESA    Elisabeth Rørbakk Jakobsen     -
# EE     Ellen Dalen                    -
# ESL    Ellen Munden Paalgard          -
# EBD    Elline                         -
# EK     Emma Tollersrud                -
# EL     Erik Holme. Hovedfagsstudent   -
# EMS    Erik Lundesgaard               -
# EDD    Erlend Bergsås Mikkelsen       -
# EW     Eskil Pedersen                 -
# EG     Espen Dahl Hjort               -
# EP     Eva Raaum Christensen          -
# FL     Framtid                        -
# FA     Frederik Zimmer Jus–Professor  -
# FP     Fredrik Øren Refsnes           -
# GO     Gammel Traver                  -
# GM     Geir Inge Storli               -
# GH     Gin&Tonic                      -
# GKJ    Greg Mccartan                  -
# GS     Guro Havro Bjørnstad           gurosommer
# HJK    Haakon Gunnerud                -
# HL     Håken Lid                     haakenlid
# HB     Håken Lid                      -
# HM     Håkon Høgetveit                -
# HRB    Håkon Randgaard Mikalsen       -
# HG     Håkon Sukuvara                -
# HFT    Halvard Leira                  -
# HH     Hannah Berg                    -
# HKH    Hanna Krange                   -
# HMK    Hanna Kristin Hjardar          -
# HS     Hanna Magnusson                -
# HMLS   Hanne Marie Iaursulëiel Pedersen-Eriksen -
# HOH    Hanne Minde                    -
# HDH    Hans Christian Paulsen         -
# HOR    Hans Martin Austestad          -
# HFB    Hans Prydz                     -
# HN     Helena Lauvrak                 -
# HK     Helene Bjerke Fredheim         -
# HG     Helle Bendixen                 -
# HD     Henning Warloe                 -
# HAS    Henrik Ameln Hoem              -
# HE     Henrik Bjørndalen              -
# HBR    Hf-Lista                       -
# HR     Hilde Opoku                    -
# IHG    Ida Fjeldbraaten               -
# IHS    Ida Hestmann                   -
# IK     Ida Hove Solberg               -
# IMJ    Ida Madsen Hestman             -
# IB     Ida Marie Jahr                 -
# IW     Ida Waal                       -
# IRN    Ifikk                          -
# IHS    Inga Bostad                    -
# IS     Ingjerd Lindeland              -
# IHK    Ingrid Gipling                 -
# IJ     Ingrid Hoff                    -
# IST    Iselin Rud-Goksøyr             -
# IK     Isis Sunniva Deleon            -
# JFK    Jannicke Nilsen                -
# JY     Jens Vaagen                    -
# JB     Joppe                          -
# JK     Jørgen Holst                   -
# JS     Jostein Starrfelt              -
# JIU    Jo Straube                     -
# JH     Julie Estdahl                  -
# KMD    Kaja Svensson                  -
# KSTB   Kamilla Simonnes               -
# KK     Kamilla Stølen                 -
# KE     Kari Bu                        karieiring
# KE     Karoline Tynes                 -
# KB     Kenneth Wangen                 -
# KN     Kevin Sivertsen                -
# KHW    Kinderjenta                    -
# KL     Klara Furuberg                 -
# KRN    Kristian Ranestad              -
# KEK    Kristian Wikborg Wiese         -
# KH     Kristina Elisabet Kvammen      -
# KAB    Kristina Leganger              -
# KG     Kristine Djuvik Kro            -
# KN     Kristin Holvik                 -
# KHE    Kristoffer Guttorm Camillo Pedersen -
# LK     Lars Klottrup Berge            -
# LMK    Leif Lømo                      -
# LN     Lena Jensen                    -
# LHR    Lene Hoem                      -
# LSN    Lene Hopland Bergset           -
# LK     Lennart A. Lie-Havstein        -
# LH     Line Fallan Sørensen           -
# LO     Line Merete Karlsøen           -
# LOS    Line Ørnes                     -
# LB     Lisbeth Dyrberg                -
# LF     Lise Blekastad                 -
# LRBL   Liv Marit Rørvik               -
# LB     Lord Yellowjumper              -
# LS     Lovey                          -
# LF     Lovise Steinkjellå             -
# LLIF   Lucas H. Weldeghebriel         luclucas
# ML     Magnus Lange                   -
# MWA    Magnus Sparre                  -
# MZ     Mani Hussaini                  zadeh
# ML     Margrethe Gustavsen            -
# MVS    Margrethe Løøv                 -
# MMJ    Maria Mår                      -
# MD     Marianne Barstein              -
# MGT    Marianne Giske                 -
# MKS    Marianne Høva Rustberggard     -
# MH     Marie Træland                  -
# MLH    Mari Lund Arnem                -
# MM     Mari Mamre                     -
# MNP    Marius Næss Olsen              -
# MO     Marte Nubdal                   -
# MR     Marte Øien                     -
# MAV    Marte Stendstad                -
# MO     Marthe Oldernes                -
# MAD    Marthe Olstad                  -
# MEL    Martin Bergesen                -
# MP     Martin Lerstang Mikkelsen      -
# MRN    Masturbera                     mathea
# MR     Mathias Johannessen            -
# MOMJ   Mathilde Bålsrud Mjelva        -
# MC     Matias Bals                    matilde
# MSC    Matilde Clemetsen              -
# MKS    Mats Sivertsen                 -
# MLLKB  Melike Leblebicioğlu           -
# MF     Melike Leblebicio?Lu Ketil Blom -
# MF     Mia Caroline Bratz             -
# MB     Mia Frogner                    -
# MH     Mjøsen Golfklubb               -
# MT     Mona Helene Grønlie            -
# MH     Morten Grinna Normann          -
# NWL    Natasza K. Bogacz              -
# NPP    Nicolai Gulowsen               -
# NW     Nicolay Stang                  -
# NL     Nik. Brandal                   -
# NPS    Nils Norman Haukås             -
# NT     Nord–Afrikakunnskap            -
# OD     Odd Vegard Paulsen             -
# OJ     Odin Hørthe Omdal              -
# OH     Øivind Bratberg                -
# OV     Ola Vassli                     -
# OH     Olav Event                     -
# OHE    Ole-Fredrik Lambertsen         -
# OHE    Ole Heier Engeset              -
# OHF    Ole Henrik Ellestad            -
# OS     Olga S. Meh                    -
# OG     Øystein Engedal                -
# OA     Øyunn Syrstad Høydal           -
# OGSD   Øyvind Gallefoss               -
# OL     Øyvind Kind Robertsen          -
# PA     Øyvind Sundstrøm               -
# PSS    Partynorsk                     -
# PAW    Patrick Egersborg              -
# PPB    Paul Grini                     -
# PF     Petter Brønstad                -
# PH     Petter Haas Brubakk            -
# PAJ    Petter Risøe                   -
# P      Poteten                        -
# RT     Ragnar Lie                     -
# RP     Rahma Søvik                    -
# RE     Riboflav                       -
# RBF    Rita Helgesen                  roarblasmo
# RBBF   Roar Blåsmo-Falnes             -
# RRJ    Robin Håset Drager             -
# RO     Rune Olav Horstad              -
# SB     Samselius                      -
# SN     Sara Moss                      -
# SAG    Sebastian Andersen             -
# SD     Sebastian Asbjørn Gabrielsen   -
# SRH    Signe Bakke Johannessen        -
# SE     Silje Christine Andersen       -
# SK     Silje Haugland                 -
# SR     Silje Kleven                   -
# S      Silje Solberg                  -
# SAA    Simen André Knuttsøn           -
# SGM    Simon Christian Osen           -
# STL    Sindre Granly Meldalen         -
# SOE    Siri Nerbø                     -
# SS     Sjur Øvrebø                    -
# SBV    Sjur Stølen                    -
# SSE    Solveig Østrem                 -
# SL     Stentrollet Fra Västergötland  -
# SH     Stéphane Lelarge               -
# SS     Stine Rotnes                   -
# S      Studinen                       -
# SRS    Sunniva Ørstavik               -
# ST     Sunniva R. Skjeggestad         -
# SS     Superpus                       -
# SEH    Svein Angleskår                -
# SH     Svein Tømmerdal D.Y            -
# TH     Teresa Eltervåg Cissé          -
# TGR    Thea Bech                      -
# TSE    Thea Skyvulstad                -
# TJ     Therese Eia Lerøen             -
# TKB    Thorbjørn Kringlebotn          -
# TM     Tobias Lund                    tobiasmyrland
# TCST   Tom Skramstad                  -
# TN     Tonje Eliasson                 -
# TT     Tonje Næss                     -
# TSH    Torbjørn Røe Isaksen           -
# TSA    Toril Roberg                   -
# TBMH   Truls Oftedal Ellingsen        -
# U      Ungdom For Fritt Palestina     -
# UC     Universitetet I Oslo           -
# VS     Vic Tim Ov Crime               -
# VJLS   Vida Sundseth Brenna           -
# VB     Vilde Boberg Svineng           -
# WNN    Vmnord                         -
# WB     Wanda Nathalie Nordstrøm       -
# WSC    William Tayeeba                -
# XP     Www.Statoilhydro.Com           -
# X      Xxx                            -

# %%
name = 'foo'
trans = str.maketrans('fx', 'FX')
name.translate(trans)
# Out:
# 'Foo'

# %%
# remove useless contributors
from django.db.models import Count
allcn = Contributor.objects.order_by('display_name').annotate(bl_count=Count('byline', unique=True), stint_count=Count('stint', unique=True))
for cn in allcn.filter(bl_count=0):
    if not cn.email and cn.stint_count == 0:
        print(f'{str(cn.pk):<6} {str(cn):<40} {cn.bl_count} {cn.stint_count} {cn.user} {cn.email}')
        cn.delete()
    else:
        print(cn.user)
        print(f'{str(cn.pk):<6} {str(cn):<40} {cn.bl_count} {cn.stint_count} {cn.user} {cn.email}')
# Out:
# None
# 14835  Agnete Klevstrand                        0 0 None agnete.klevstrand@gmail.com
# aleksander
# 14995  Aleksander Naug                          0 1 aleksander aleksander@madebyaleks.no
# None
# 14836  Amanda Borch Pacheco                     0 0 None amanda.borch.pacheco@gmail.com
# None
# 14994  Anna Torst Saatvedt                      0 1 None Anna_Saatvedt94@hotmail.com
# None
# 14837  Anne Garvoll                             0 0 None annegarvoll@hotmail.com
# None
# 14926  Asbjørn Slettemark                       0 1 None None
# None
# 14851  Åsmund Austenå Løvdal                    0 0 None asmundlovdal@gmail.com
# None
# 14838  Birgitte Hvidsten                        0 0 None birgitte.hvidsten@gmail.com
# None
# 14839  Bjørg Sabrin Timraz                      0 0 None bjorgsti@hotmail.no
# None
# 14840  Dennis                                   0 0 None universitas@universitas.no
# ebbatangen
# 14915  Ebba Skarland Tangen                     0 1 ebbatangen ebba.tangen@gmail.com
# None
# 14834  Geir Dorp                                0 1 None geirdo@universitas.no
# None
# 14809  Håken Lid                               0 1 None None
# None
# 14806  Håkon Sukuvara                          0 1 None None
# None
# 15014  Hilde, hva er etikk? Hilde: ehh...pensum... 0 1 None None
# None
# 14841  Hilde Mesics Kleven                      0 0 None hildemesics@gmail.com
# jspreston
# 14815  Joakim Stene Preston                     0 1 jspreston j.s.preston@universitas.no
# kaja
# 14902  Kaja Norheim                             0 1 kaja kaja.norh@gmail.com
# None
# 14842  Karoline Tynes                           0 0 None karoline.tynes@xi.no
# None
# 14804  Katrine Myra                             0 1 None katrinmy@universitas.no
# None
# 14843  Kjetil Tørum                             0 0 None kjetil.torum@gmail.com
# None
# 14844  Kristine Alsaker                         0 0 None kr.alsaker@gmail.com
# None
# 14845  Kristoffer Hunstad                       0 0 None hunstad89@gmail.com
# None
# 14983  Lukas Lehner                             0 1 None lukaslehner15@gmail.com
# None
# 14807  Marthe Olstad                            0 1 None marolsta@gmail.com
# None
# 14813  Monica Reigstad                          0 1 None monicrei@universitas.no
# None
# 14846  Odin Hørthe Omdal                        0 0 None odinho@universitas.no
# None
# 14847  Ragnhild Torstensen                      0 0 None ragnt@universitas.no
# solveigløken
# 14996  Solveig Bua Løken                        0 1 solveigløken solveig.bua@gmail.com
# sunnivaeide
# 14982  Sunniva Dorthea Tormodsdatter Eide       0 1 sunnivaeide sunniva.eide@gmail.com
# None
# 14848  Thea Bech                                0 0 None theabech@hotmail.com
# None
# 14814  Thorbjørn Kringlebotn                    0 1 None None
# None
# 14849  Vidar Bakkeli                            0 0 None vidab@universitas.no
# None
# 14850  Vincent André Placht                     0 0 None vplacht@gmail.com

# %%
hans = Contributor.objects.search("hval").exclude(display_name__contains='Olav')
from utils.merge_model_objects import merge_instances
#merge_instances(*list(hans))
hans
# Out:
# <ContributorQuerySet [<Contributor: Hans Dalane-Hval>]>

# %%
hovland = Contributor.objects.search('Øivind Hovland')[0]
illus = ImageFile.objects.filter(description__contains='ind Hovland')
illus.update(category=ImageFile.ILLUSTRATION, contributor=hovland)
# Out:
# 159
