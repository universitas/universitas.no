# %%
import re
from pprint import pprint as pp
def inlines(lines):
    tags = re.compile('^@(image|box|quote):')
    return (line for line in map(str.strip, lines) if tags.match(line))

def add_text_tag(lines):
    return (line if line.startswith('@') else f'@txt:{line}' for line in (l.strip() for l in lines) if line)

def links_to_dict(story):
    return [{'label': l.number, 'url': l.link} for l in story.inline_links.all()]

def images_to_dict(story):
    images = (im.child for im in story.images().order_by('index'))
    return [{
        'index': im.index,
        'id': im.imagefile.pk, 
        'caption': im.caption,
        'creditline': im.creditline,
        'ratio': im.aspect_ratio,
    } for im in images]

def videos_to_dict(story):
    videos = (vd.child for vd in story.videos().order_by('index'))
    return [{
        'index': vd.index,
        'link': vd.link,
        'caption': vd.caption,
        'creditline': vd.creditline,
        'ratio': vd.aspect_ratio,
    } for vd in videos]

# %%
for vid in StoryVideo.objects.all():
    print(vid.link)
# Out:
# https://vimeo.com/125951244
# https://vimeo.com/125978502
# https://vimeo.com/109002468
# https://vimeo.com/109002178
# https://vimeo.com/128929942
# https://vimeo.com/128929943
# https://vimeo.com/121352681
# https://vimeo.com/121352681
# https://vimeo.com/147010353
# https://www.youtube.com/watch?v=lAJ5KJoC18s/
# https://www.youtube.com/watch?v=E26jZB81j0Y/
# https://www.youtube.com/watch?v=o4mI9MZsQF0/
# https://www.youtube.com/watch?v=R_V_pVQCb4s/
# https://www.youtube.com/watch?v=akLs-oX2mDM/
# https://www.youtube.com/watch?v=akLs-oX2mDM/
# https://vimeo.com/216760518

# %%
def serialize_story(story):
    title = f'@tit:{story.title}' if story.title else ''
    kicker = f'@stikktit:{story.kicker}' if story.kicker else ''
    lede = f'@ing:{story.lede}' if story.lede else ''
    theme = f'@tema:{story.theme_word}' if story.theme_word else ''
    bylines = (str(bl) for bl in story.byline_set.all())
    pullquotes = (pq.pullquote.bodytext_markup for pq in story.pullquotes())
    asides = (aside.aside.bodytext_markup for aside in story.asides())
    images = list
    body = story.bodytext_markup.splitlines()
    body = add_text_tag(body)
    lines = '\n'.join([kicker, title, theme, lede, *body, *bylines, *asides, *pullquotes]).splitlines()
    return {
        'pk': story.pk,
        'text': [line for line in lines if line],
        'links': links_to_dict(story),
        'videos': videos_to_dict(story),
        'images': images_to_dict(story),
    }
  
for story in Story.objects.exclude(inline_links=None).order_by('?')[:3]:
    pp(serialize_story(story))
# Out:
# {'images': [{'caption': 'Complaining his way down: Jostein Hult went from a B '
#                         'to a fail when he complained on his grade. – The '
#                         'grading seems random when the deviations can be so '
#                         'large, he says.\u2028'
#                         '\u2028',
#              'creditline': '',
#              'id': 30193,
#              'index': 1,
#              'ratio': 0.0},
#             {'caption': 'Complained his way to the top: Karl Kristian R. '
#                         'Kirchhoff went from a D to an A, when he complained '
#                         'on his grade.\u2028'
#                         '\u2028',
#              'creditline': '',
#              'id': 30194,
#              'index': 2,
#              'ratio': 0.0}],
#  'links': [{'label': 1, 'url': 'http://oldwww.universitas.no/news/'}],
#  'pk': 60304,
#  'text': ['@tit:From B to F',
#           '@ing:While one student went from B to F, another went from D to an '
#           'A after complaining on their grades.',
#           '@txt:– I took a chance, complained and got an F. A few days later I '
#           'got the reason for the grade where the exam paper was slaughtered, '
#           'says Jostein Hult.',
#           '@txt:He’s on his last semester on China Studies at the University '
#           'of Oslo (UiO). Hult went from a B to an F after complaining on the '
#           'grade on his exam paper on Society and Politics in China. He took '
#           'the course autumn 2014 and received an answer to the complaint '
#           'recently.',
#           '@spm:*[Read more news in English here.](1)',
#           '@txt:– I was pleased with the paper and hoped for an A, but got a '
#           'B. If it were a borderline case I felt pretty sure it was between '
#           'an A and a B, not worse, he says.',
#           '@txt:I am uncertain now how much of the work you put into your '
#           'studies is worth when grades are set so arbitrary, says Hult.',
#           '@quote:  1',
#           '@txt:– You lose heart and think that it does not matter whether you '
#           'study for the exam or not. Grading seems random when the deviations '
#           'can be so large, he says.',
#           '@mt:Blind grading',
#           '@txt:The practice of blind appeal was introduced at all Norwegian '
#           'universities and colleges autumn 2014 by a parliamentary '
#           'resolution. This implies that complaint censors will not know which '
#           'grade the paper originally got.',
#           '@txt:UiO previously practiced open censorship. When students '
#           'complained, the second censors got to know the original grade '
#           "together with the student's grounds for appeal. With blind "
#           'censorship there is no longer a need for the student to give a '
#           'reason for the complaint.',
#           '@txt:Hult is sceptical to the practice of blind censorship.',
#           "@txt:– It's easier to see how the matter stands if you know the "
#           'original grade. It’s a bit like jeopardy when someone outside is to '
#           'grade you without knowing anything about the setting, he says.',
#           '@txt:The failing grade can have major consequences for the China '
#           'student.',
#           '@txt:– If I fail, I won’t get my bachelor as planned. I have '
#           'applied for an exchange to China this autumn. To retake the '
#           'subject, I must take the exam while doing an intense study there, '
#           'says Hult.',
#           '@mt:Unfortunate',
#           '@txt:Section Manager at Faculty of Humanities, Gro Enerstvedt '
#           'Smenes, says that the department has been in touch with the faculty '
#           'leadership as the variations between the grades given were so '
#           'great.',
#           '@txt:– This is unfortunate for the student in question. The case is '
#           'being investigated to find out what has happened and to make sure '
#           'it will be followed up fairly. According to the Universities and '
#           'Colleges Act an appeal is final. The decision cannot be modified, '
#           'says Smenes.',
#           '@txt:She says that the Faculty of Arts is paying attention on '
#           'whether blind censorship can affect the complainer’s grades.',
#           '@txt:– As I understand it, the experience throughout the whole '
#           'higher education sector is that blind censorship creates more '
#           'variations than the former process of knowing the grade and '
#           'complaint, she says.',
#           '@mt:From D to A',
#           '@image: > 2',
#           '@txt:Law student Karl Kristian Rådal Kirchhoff, however, has a '
#           'positive experience with blind censorship. He went from D to A '
#           'after he complained on his grade in the course Method and Ethics. '
#           'Kirchhoff believes this shows good practice.',
#           '@txt:– By using blind censorship you get a real second-time '
#           'assessment of the grade. Some studies show that there is a high '
#           'probability that the grade can be influenced by the examiner '
#           'knowing the original grade. A second-time assessment can therefore '
#           'contribute to a more accurate assessment, he says.',
#           '@txt:Kirchhoff does not think coincidences are an element when '
#           'grades are set.',
#           '@txt:– Some subjects, especially in the social sciences, have an '
#           'element of discretion in them. You can hit the mark more or less '
#           'well with one censor, but poorer with another. You then have an '
#           'advantage when appealing, says Kirchhoff.',
#           '@mt:Should not happen',
#           '@txt:Dean Trygve Bergsåker at the Faculty of Law does not know the '
#           'individual case, but is sceptical of this type of discrepancy in '
#           'grading.',
#           '@txt:– To go from a D to an A sounds unusual and I do not know of '
#           'similar cases. Such deviations should not happen. I dislike it, '
#           'though I can’t say how it might have happened, he says.',
#           '@txt:He also believes the likelihood of such deviation is larger by '
#           'blind censorship.',
#           '@txt:– Blind censorship is an adequate way of conducting the appeal '
#           'procedure, but I think it would have been difficult to go from D to '
#           'A if the censor had been aware of the complainer’s grade, says '
#           'Bergsåker.',
#           '@mt:Sceptical to blind censorship',
#           '@txt:Kai A. Olsen, professor of computer science at Molde '
#           'University College is one of those who have spoken out against the '
#           'practice of blind censorship. He argues that grades are not '
#           'absolute, and that they will be influenced at all times by what '
#           'grades other students receive.',
#           '@txt:– Grades are not something that is absolute and can’t be '
#           'calculated with a formula. Other students’ achievements will always '
#           'affect the grading. If the others do well and you average, you may '
#           'end up getting a worse grade than you would have if you do better '
#           'than average, says Olsen.',
#           '@txt:One of his own students also experienced going from C to '
#           'failing. He also believes that deviations in the grading become '
#           'more common with blind censorship.',
#           '@txt:– With blind censorship you only get one answer, and there '
#           'might be bigger deviations in the grading. Eventually we will adapt '
#           'to a blind system and deviations would then decrease, he says.',
#           '@txt:He proposes to amend the complaint system by giving the '
#           'student the opportunity to explain herself. Olsen proposes to amend '
#           'the right to send «complain about censorship» to the right to send '
#           '«academically grounded complain about censorship.»',
#           '@txt:– Many students are intelligent and may have read recent '
#           'research in addition to the curriculum that they include in the '
#           'answer. Then they must have the opportunity to explain themselves, '
#           'he says.',
#           '@spm:Translated by Louise Faldalen Prytz',
#           '@bl: Tekst: Lene Christensen',
#           '@bl: Foto: Matthis Kleeb Solheim',
#           '@sitat:«Grading seems random when deviations can be so large.»',
#           '@sitatbyline:Jostein Hult'],
#  'videos': []}
# {'images': [{'caption': 'Dream study: Kjetil Mikael Sortland (left), Peder '
#                         'Pili Strand (middle) and Kristine Heimdal (right) '
#                         'believe studying architecture is more fun than '
#                         'work.\u2028'
#                         '\u2028',
#              'creditline': '',
#              'id': 30364,
#              'index': 1,
#              'ratio': 0.0},
#             {'caption': 'Focused: Henning Sørensen (left) and Chris Philip '
#                         'Stangeby (right) sit in the BI building in Nydalen '
#                         'working on assignments.\u2028'
#                         '\u2028',
#              'creditline': '',
#              'id': 30365,
#              'index': 2,
#              'ratio': 0.0},
#             {'caption': 'Discipline: Silje Hegre (left) and Emilie Hamansen '
#                         '(right) believe in the importance of studying '
#                         'regularly to avoid an all-out effort just before '
#                         'exams.',
#              'creditline': '',
#              'id': 30366,
#              'index': 3,
#              'ratio': 0.0}],
#  'links': [{'label': 1, 'url': 'http://oldwww.universitas.no/news/'}],
#  'pk': 60421,
#  'text': ['@tit:Students in Bergen study most',
#           '@ing:Students at NHH (Norwegian School of Economics) spend eleven '
#           'hours more on schoolwork than BI (Norwegian Business School) '
#           'students.',
#           '@quote:  1',
#           '@txt:Students at NHH spend an average of 40 hours studying a week. '
#           'That’s 11 hours more than students at BI, who on average spend 29 '
#           'hours a week studying.',
#           '@txt:These numbers are from a comparison based on the Norwegian '
#           'Agency for Quality Assurance in Education (NOKUT) study barometer.',
#           '@spm:*[Read more news in English here.](1)',
#           '@txt:The hardest working students attend Bergen Architecture '
#           'College (BAS), where the students spend on average 55 hours a week '
#           'on professional activities. That’s more than twice as much as '
#           'students at the University College of Nesna, the University College '
#           "with the country's least hardworking students, with a study average "
#           'of 23 hours.',
#           '@txt:Head of Administration at BI Kjersti Gummerson, believes that '
#           'too much shouldn’t be read into the numbers, partly because the '
#           'study barometer merged study hours for both master and bachelor '
#           'students.',
#           '@txt:– The result being that it doesn’t show that master students '
#           'at BI spend 42 hours per week on professional activity, says '
#           'Gummerson, adding that this puts graduate students at BI in the top '
#           'echelon.',
#           '@txt:Bachelor students at BI, however, rank below average, spending '
#           'around 26 hours a week on schoolwork. Gummerson does not comment on '
#           'this.',
#           '@mt:High dropout rate',
#           '@image: > 2',
#           '@image: > 3',
#           '@txt:Real Estate students Silje Hegre, Emilie Hamansen Henning '
#           'Sørensen and Chris Philip Stangeby are sitting around a table '
#           'working on assignments. They are BI students in Nydalen and believe '
#           'it is easier to acquire good reading habits, the longer you have '
#           'studied.',
#           '@txt:– I read more evenly throughout the semester now than earlier '
#           'in the programme, says Hegre.',
#           '@txt:The students agree that not everyone is equally dedicated at '
#           'BI. Hamansen points out that many have fallen off since the '
#           'beginning of the studies, while Hegre holds that some students '
#           'apply to BI because they do not quite know what they want and want '
#           'to try out some options.',
#           '@mt:An unfair reputation',
#           '@txt:Stangeby believes that BI has an unfair reputation. He states '
#           'that real estate is a profession where what you do outside the '
#           'curriculum is as important as reading.',
#           "@txt:– I'm on different lectures with business people and has just "
#           'gotten a study related job, says Stangeby, who believes such '
#           'activities do not show up clearly in the study barometer.',
#           '@txt:With the curriculum in front of them the students believe that '
#           'they have found a good formula for learning.',
#           '@txt:– Working in groups and by mandatory assignments (arbeidskrav) '
#           'always works best, says Sørensen.',
#           '@txt:Kjetil Bjorvatn is dean at NHH.',
#           '@txt:He will not compare NHH and BI, but believes there is a '
#           'correlation between time spent on studying and learning. He is '
#           "satisfied with NHH students' academic activity.",
#           "@txt:– We accept some of the country's most talented students, says "
#           'Bjorvatn.',
#           '@txt:He believes that students at NHH work so hard because the '
#           'school expects a lot from them and that students expect a lot of '
#           'the school. The dean adds nonetheless that NHH students must be '
#           'even better to read evenly throughout the semester to avoid all-out '
#           'bursts before the exam.',
#           '@mt:Architecture students most diligent',
#           '@txt:At the top of NOKUT’s study barometer of the time spent '
#           'studying thrones Bergen Architecture College (BAS), where students '
#           'spend on average 55 hours per week on professional activities.',
#           '@txt:Cecilie Andersson is rector at BAS and believes there is a '
#           'connection between architecture students’ diligence and school '
#           'admissions.',
#           '@txt:– We do not admit students through regular admission, but '
#           'through interviews, says Andersson.',
#           '@txt:She thinks they already then note who is really passionate '
#           'about architecture.',
#           '@txt:At BAS, exams are rated by pass or fail. Although students can '
#           'gamble on meeting the minimum requirements they choose rather to be '
#           'ambitious and to be as good as possible, believes Andersson.',
#           '@txt:– For our students, it is a lifestyle, says the rector.',
#           '@mt:More than a job',
#           '@txt:Oslo School of Architecture and Design (AHO) ended up in '
#           'fourth place in the study barometer with 49 hours a week on '
#           'schoolwork.',
#           '@txt:Communications Manager Trude Kleven also points out that AHO '
#           'students must go through special admission. In addition, she '
#           'describes the students as motivated and hardworking.',
#           '@txt:Kristine Heimdal, Peder Pili Beach and Kjetil Mikael Sortland '
#           'are sitting in the library at AHO with a model of the Viking Ship '
#           'Museum, their final exam project. The students think it is easier '
#           'to stay motivated when you are allowed to develop and refine your '
#           'own project.',
#           '@txt:AHO is, like BAS, always open, and if the students are to be '
#           'believed they are also in place there at night. According to '
#           'Sortland the student gang have spent several nights on the school '
#           'premises. They don’t find that problematic.',
#           '@txt:– This is more than a job for us, says Strand.',
#           "@txt:– It's a lifestyle, adds Heimdal.",
#           '@txt:Nesna ended at the bottom of the list. Students at Nesna spend '
#           'only 23 hours on schoolwork a week. Nesna would not comment on the '
#           'matter.',
#           '@spm:Translated by Louise Faldalen Prytz',
#           '@bl: Tekst: Hanad Mohamed Ali',
#           '@bl: Foto: Silje Kleven',
#           '@sitat:«Architecture is a lifestyle.»',
#           '@sitatbyline:Kristine Heimdal, architecture student at Oslo School '
#           'of Architecture and Design'],
#  'videos': []}
# {'images': [{'caption': 'STORE MØRKETALL: En vanlig forelesningssal er full av '
#                         'studenter som kommer til å jukse på eksamen.',
#              'creditline': '',
#              'id': 21412,
#              'index': 1,
#              'ratio': 0.0}],
#  'links': [{'label': 1,
#             'url': '/nyheter/54666/17-tatt-for-juks-ved-uio-i-2009'}],
#  'pk': 54732,
#  'text': ['@tit:1 av 20 har jukset på eksamen',
#           '@tema:JUKS',
#           '@ing:Langt flere enn de som tas i fusk ved UiO innrømmer å ha '
#           'jukset på eksamen. Minst 9 av 10 juksere slipper unna.',
#           'Gjennomsnittlig jukser 1 av 20 studenter. For studentene som oppgir '
#           'Frp eller Venstre som partipreferanse er tallet dobbelt så stort.',
#           '@box: > 1',
#           '@txt:– Det er nedslående at så mange sier at de jukser, sier Monica '
#           'Bakken, Studiedirektør ved Universitetet i Oslo (UiO).',
#           '@txt:Fem prosent av norske studenter innrømmer å ha jukset på '
#           'eksamen. Dette kommer fram i en undersøkelse utført av Sentio for '
#           'Universitas. Av UiOs omtrent 28 000 studenter vil dette i dag '
#           'tilsvare rundt 1400 studenter.',
#           '@txt:Universitas skrev forrige uke om [«Petra» som jukser på minst '
#           'én eksamen i semesteret](1), og om at stadig færre studenter blir '
#           'tatt i juks ved UiO. Tall fra UiOs klagenemd viser at universitetet '
#           'bare har tatt mellom 15 og 30 studenter i året for juks siden 2004, '
#           'totalt 132 studenter på seks år. Det betyr at minst 9 av 10 slipper '
#           'unna med fusk.',
#           '@mt:Sterkt fokus på juks ved UiO',
#           '@txt:Bakken tror det er en økende tendens til å ta snarveier i '
#           'samfunnet som en helhet, ikke bare i utdanningssektoren.',
#           '@txt:– Juksesaker er det jeg har blitt intervjuet mest om av '
#           'pressen de to siste årene, sier Bakken.',
#           '@txt:Hun forteller at UiO jobber hardt med kontroller, gjennom '
#           'elektronisk plagieringsverktøy, i eksamenslokalene, og med '
#           'holdningsskapende arbeid. Det er også vesentlig å lære opp nye '
#           'studenter i kildebruk. Mange som kommer rett fra videregående vet '
#           'ikke hva som anses som juks, ifølge Bakken.',
#           '@txt:– Vi må fortsatt ha sterkt fokus på juks, og vi må intensivere '
#           'både holdningsarbeidet og kontrollene som utføres. Vi må holde '
#           'trykket oppe. Spesielt er det viktig å trappe opp bruken av '
#           'plagieringsverktøy.',
#           '@mt:KD ikke bekymret',
#           '@txt:Statssekretær i Kunnskapsdepartementet (KD) Kyrre Lekve kan '
#           'fortelle at KD ikke ser på juks i utdanningssektoren som et stort '
#           'problem.',
#           '@quote:  1',
#           '@txt:– Det er store gradsforskjeller i hva folk legger i begrepet '
#           'juks. Man kan helt sikkert bli bedre, men man kan aldri ta alle som '
#           'jukser, sier Lekve.',
#           '@txt:Lekve mener at de metodene man i dag har for å forhindre juks '
#           'er gode nok.',
#           '@txt:– Det er studentenes moral som til syvende og sist er det '
#           'avgjørende her, uansett hvilke mekanismer vi setter i gang. Det '
#           'store bildet er at 95 prosent ikke jukser, sier han.',
#           '@mt:Studentrepresentantene opprørt',
#           '@txt:Leder i Studentutvalget ved Det samfunnsvitenskapelig fakultet '
#           '(SV) ved UiO Knut Ulsrud mener at tallene viser at kontrollrutinene '
#           'ikke er gode nok.',
#           '@txt:– Systemet er åpenbart utilstrekkelig når det viser seg at så '
#           'mange kommer unna med juks, sier Ulsrud.',
#           '@txt:Ved Det matematisk-naturvitenskapelige fakultet er leder i '
#           'Studentutvalget Ingunn Sandberg enig med Ulsrud.',
#           '@txt:– Hvis disse tallene stemmer, synes jeg det er helt '
#           'forferdelig, sier Sandberg.',
#           '@txt:Ulsrud også misfornøyd med kontrollen under de skriftlige '
#           'eksamenene ved SV-fakultetet.',
#           '@txt:– Det er nødvendig med bedre opplæring og oppfølging av '
#           'eksamensvaktene, sier han.',
#           '@mt:– Fakultetene må ta ansvaret',
#           '@txt:Studiedirektør Bakken mener at kvaliteten på kontroll i '
#           'eksamenslokalene er gjennomgående god, men sier allikevel at '
#           'kontrollen eksamensvaktene utøver kan variere fra fakultet til '
#           'fakultet.',
#           '@txt:– Det sjekkes grundig under skriftlig eksamen. Til og med '
#           'toalettene undersøkes for jukselapper før, under og etter eksamen, '
#           'sier hun.',
#           '@txt:Men det er hvert enkelt fakultet som har ansvar for sine '
#           'eksamensvakter.',
#           '@txt:Avdelingsleder ved fakultetsadministrasjonen på SV-fakultetet '
#           'Tone Vold-Johansen mener at eksamensvaktene de har er kompetente.',
#           '@txt:– Vi stiller krav til eksamensvaktene våre. De må gjennom et '
#           'strengt intervju, og de skal være oppegående, sier hun.',
#           '@mt:Snakket sammen på do',
#           '@txt:Professor Trond Nordby ved Institutt for statsvitenskap kan '
#           'imidlertid bekrefte at eksamensvakter ikke alltid gjør jobben sin. '
#           'Han kan fortelle at han en gang avslørte to studenter som jukset på '
#           'toalettet i Frederikkebygningen.',
#           '@txt:– Det stod to studenter og snakket høylydt sammen inne i en '
#           'bås. Jeg sa fra til eksamensvaktene som stod utenfor toalettet, men '
#           'det virket ikke som de brydde seg, sier han.',
#           '@txt:– Men ellers har jeg aldri sett noe særlig til juks blant '
#           'studenter, selv om jeg har vært sensor i mange år, sier Nordby.',
#           '@txt:Han forteller imidlertid at han ikke bruker '
#           'plagieringsverktøyene som er tilgjengelige ved UiO i noen særlig '
#           'grad.',
#           '@txt:– Jeg har ikke følt noe spesielt behov for det.',
#           '@mt:Verre i resten av landet',
#           '@txt:Ved de andre store universitetene i landet tas det enda færre '
#           'juksere enn ved UiO. De siste seks årene har Universitetet i Bergen '
#           'og NTNU til sammen tatt 142 studenter for juks, altså omtrent det '
#           'samme antallet som UiO har tatt alene i løpet av disse årene.',
#           '@txt:Kyrre Lekve mener allikevel at institusjonene gjør en god nok '
#           'jobb.',
#           '@txt:– Jeg tror at det arbeidet som er satt i gang vil gi gode '
#           'resultater fremover, sier han.',
#           '@txt:Monica Bakken mener også at det ikke er så mye mer enn det de '
#           'allerede gjør, som kan gjøres.',
#           '@txt:– Vi gjør det så bra vi kan, ut i fra det vi kan gjøre, sier '
#           'hun.',
#           '@txt:– I de utsatte partienes ungdomsorganisasjoner er man '
#           'forbauset over disse tallene. Her mener man at det ikke er noen '
#           'grunn til at moderpartiene deres skulle tiltrekke seg spesielt '
#           'uredelige personer.',
#           '@txt:– Dette overrasker meg stort.Vi er et parti som er opptatt av '
#           'lov og orden, sier leder i Fremskrittspartiets Ungdom, Ove Vanebo.',
#           '@txt:En av ti studenter som stemmer Venstre jukser, ifølge '
#           'Sentio-undersøkelsen. For Fremskrittspartiet (Frp) er tallene på '
#           'hele tolv prosent. Blant de fleste andre politiske partier ligger '
#           'tallet på mellom null og tre prosent av studentene som stemmer på '
#           'dem.',
#           '@txt:– Både Venstre og Frp er partier som er opptatt av individuell '
#           'frihet, men betyr ikke at det er snakk om en frihet til å jukse, '
#           'sier Vanebo.',
#           '@txt:Leder i Unge Venstre Anne Solsvik mener at det er trist hvis '
#           'deres velgere jukser mer enn andre.',
#           '@txt:– Jeg vet ikke helt hva jeg skal si, det var kjedelig å høre, '
#           'sier hun.',
#           '@bl: Tekst: Hallvard Østtveit Barbogen',
#           '@bl: Foto: Ketil Blom',
#           '@fakta:*Eksamensjuks:*',
#           '@li:1001 studenter ble spurt om hvor mange ganger de har jukset på '
#           'eksamen:',
#           '@li:95 prosent svarte at de aldri har jukset.',
#           '@li:3 prosent svarte at de har jukset en gang.',
#           '@li:2 prosent svarte at de har jukset to eller flere ganger.',
#           '@li:Undersøkelsen er utført av Sentio Research Norge for '
#           'Universitas.',
#           '@undersaktit:De liberale jukser mest',
#           '@sitat:– Man kan helt sikkert bli bedre, men man kan aldri ta alle '
#           'som jukser.',
#           '@sitatbyline:Kyrre Lekve, statssekretær i kunnskapsdepartementet'],
#  'videos': []}

# %%
story = Story.objects.get(pk=53597)
serialize_story(story)

# %%
list(inlines(story.bodytext_markup.splitlines()))

# %%
[im.storyimage for im in story.images()]

# %%
[(el.index, el.child) for el in story.storyelement_set.all()]

# %%
story = Story.objects.exclude(inline_links=None).order_by('?').first()
list(story.inline_links.all())
