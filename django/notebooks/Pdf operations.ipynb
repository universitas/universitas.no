# %% [markdown]
# Pdf operations should work both on local file backend and boto / aws

# %%
from apps.issues.models import pdf_to_image, pdf_to_text

# %%
iss = PrintIssue.objects.first()

# %%
pdf_to_image(iss.pdf)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b563574060c5> in <module>()
# ----> 1 pdf_to_image(iss.pdf)
#
# /app/apps/issues/models.py in pdf_to_image(pdf, page, resolution, file_format)
#      66 def pdf_to_image(pdf, page=1, resolution=60, file_format='jpeg'):
#      67     """Creates a image file from pdf file"""
# ---> 68     reader = PyPDF2.PdfFileReader(pdf, strict=False)
#      69     writer = PyPDF2.PdfFileWriter()
#      70     writer.addPage(reader.getPage(page - 1))
#
# /usr/local/lib/python3.6/site-packages/PyPDF2/pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
# -> 1084         self.read(stream)
#    1085         self.stream = stream
#    1086
#
# /usr/local/lib/python3.6/site-packages/PyPDF2/pdf.py in read(self, stream)
# ...

# %%
issues = []
for iss in PrintIssue.objects.all():
    try: 
        pdf = iss.pdf.file
        print(pdf) 
        issues.append(iss)
    except FileNotFoundError:
        pass
# Out:
# /var/media/pdf/8f7b66a2e82a11e68c22f23c916e5154/universitas_2017-4.pdf
# /var/media/pdf/0aae96f6f8ab11e68c22f23c916e5154/universitas_2017-7.pdf
# /var/media/pdf/dc03a8b4d7e411e6b0dcf23c916e5154/universitas_2017-1.pdf
# /var/media/pdf/3d392c0edd2a11e6b0dcf23c916e5154/universitas_2017-2.pdf
# /var/media/pdf/647a9430e2aa11e6b0dcf23c916e5154/universitas_2017-3.pdf
# /var/media/pdf/30ca25befe2b11e68c22f23c916e5154/universitas_2017-8.pdf
# /var/media/pdf/5b8bd65a03ab11e78c22f23c916e5154/universitas_2017-9.pdf
# /var/media/pdf/b99ba836edaa11e68c22f23c916e5154/universitas_2017-5.pdf
# /var/media/pdf/e093fe7cf32a11e68c22f23c916e5154/universitas_2017-6.pdf
# /var/media/pdf/b1a145880eab11e7aa6bf23c916e5154/universitas_2017-11_mag.pdf
# /var/media/pdf/83ec4a64092b11e7aa6bf23c916e5154/universitas_2017-10.pdf
# /var/media/pdf/aafc683e0eab11e7aa6bf23c916e5154/universitas_2017-11.pdf

# %%
pdf = issues[0].pdf.file
pdf_to_image(pdf)
# Out:
# <wand.image.Image: 0261316 'JPEG' (661x947)>

# %%
pdf_to_text(pdf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-df7d04b6b748> in <module>()
# ----> 1 pdf_to_text(pdf)
#
# /app/apps/issues/models.py in pdf_to_text(pdf_data, first_page, last_page)
#      57     args = [str(a) for a in args]
#      58     text = subprocess.run(
# ---> 59         args, check=True, stdout=subprocess.PIPE, input=pdf_data,
#      60     ).stdout.decode()
#      61     text = unicodedata.normalize('NFKD', text).strip()
#
# /usr/local/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     403     with Popen(*popenargs, **kwargs) as process:
#     404         try:
# --> 405             stdout, stderr = process.communicate(input, timeout=timeout)
#     406         except TimeoutExpired:
#     407             process.kill()
#
# /usr/local/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     834
# ...
